# %%
import sqlalchemy
import pandas as pd

# %%
import os

#
# Start with avgHiLo
#

path = '/Users/jameshayes/'
file_name = 'avgHiLo.csv'
full_file = f'{path}{file_name}'
df = pd.read_csv(full_file, index_col=False)
tableName = 'avgHiLo'

#
# use environmental variables for the SQL query
#

db_user = os.environ.get('dbUser')
db_password = os.environ.get('dbPass')

database_username = db_user
database_password = db_password
database_ip       = '3.135.162.69'
database_name     = 'trweather'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name), connect_args={'connect_timeout': 30})
print(database_connection)
df.to_sql(con=database_connection, name='avgHiLo', if_exists='replace')

# %%
#
# Next is avgTemps
#

path = '/Users/jameshayes/'
file_name = 'avgTemps.csv'
full_file = f'{path}{file_name}'
df = pd.read_csv(full_file, index_col=False)
tableName = 'avgTemps'

database_username = db_user
database_password = db_password
database_ip       = '3.135.162.69'
database_name     = 'trweather'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name), connect_args={'connect_timeout': 30})
print(database_connection)
df.to_sql(con=database_connection, name='avgTemps', if_exists='replace')

# %%
#
# Next is dailyAvgTemps
#

path = '/Users/jameshayes/'
file_name = 'dailyAvgTemps.csv'
full_file = f'{path}{file_name}'
df = pd.read_csv(full_file, index_col=False)
tableName = 'dailyAvgTemps'

database_username = db_user
database_password = db_password
database_ip       = '3.135.162.69'
database_name     = 'trweather'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name), connect_args={'connect_timeout': 30})
print(database_connection)
df.to_sql(con=database_connection, name='dailyAvgTemps', if_exists='replace')

# %%
#
# Next is maxOfMin
#

path = '/Users/jameshayes/'
file_name = 'maxOfMin.csv'
full_file = f'{path}{file_name}'
df = pd.read_csv(full_file, index_col=False)
tableName = 'maxOfMin'

database_username = db_user
database_password = db_password
database_ip       = '3.135.162.69'
database_name     = 'trweather'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name), connect_args={'connect_timeout': 30})
print(database_connection)
df.to_sql(con=database_connection, name='maxOfMin', if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       6 file_name = 'maxOfMin.csv'
#       7 full_file = f'{path}{file_name}'
# ----> 8 df = pd.read_csv(full_file, index_col=False)
#       9 tableName = 'maxOfMin'
#      11 database_username = 'chuckwx'
#
# NameError: name 'pd' is not defined

# %%
#
# Next is minOfMax
#

path = '/Users/jameshayes/'
file_name = 'minOfMax.csv'
full_file = f'{path}{file_name}'
df = pd.read_csv(full_file, index_col=False)
tableName = 'minOfMax'

database_username = 'chuckwx'
database_password = 'jfr716!!00'
database_ip       = '3.135.162.69'
database_name     = 'trweather'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name), connect_args={'connect_timeout': 30})
print(database_connection)
df.to_sql(con=database_connection, name='minOfMax', if_exists='replace')

# %%
#
# Next is recHigh
#

path = '/Users/jameshayes/'
file_name = 'RecHigh.csv'
full_file = f'{path}{file_name}'
df = pd.read_csv(full_file, index_col=False)
tableName = 'recHigh'

database_username = 'chuckwx'
database_password = 'jfr716!!00'
database_ip       = '3.135.162.69'
database_name     = 'trweather'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name), connect_args={'connect_timeout': 30})
print(database_connection)
df.to_sql(con=database_connection, name='recHigh', if_exists='replace')

# %%
#
# Next is recLow
#

path = '/Users/jameshayes/'
file_name = 'RecLow.csv'
full_file = f'{path}{file_name}'
df = pd.read_csv(full_file, index_col=False)
tableName = 'recLow'

database_username = 'chuckwx'
database_password = 'jfr716!!00'
database_ip       = '3.135.162.69'
database_name     = 'trweather'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name), connect_args={'connect_timeout': 30})
print(database_connection)
df.to_sql(con=database_connection, name='recLow', if_exists='replace')

# %%
#
# Finally trweather itself
#

path = '/Users/jameshayes/'
file_name = 'trweather.csv'
full_file = f'{path}{file_name}'
df = pd.read_csv(full_file, index_col=False)
tableName = 'trweather'

database_username = 'chuckwx'
database_password = 'jfr716!!00'
database_ip       = '3.135.162.69'
database_name     = 'trweather'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name), connect_args={'connect_timeout': 30})
print(database_connection)
df.to_sql(con=database_connection, name='trweather', if_exists='replace')
