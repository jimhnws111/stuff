# %%
import json
import urllib
import requests
import csv
import re
import pandas as pd
import sys
import collections
import datetime as datetime
from datetime import datetime  
from datetime import timezone
import numpy as np

# %%
#
# reads in the JSON file as a Python dictionary
# should be the same directory into which the data file
# was written - most likely the installation directory
# filename is synoptic.json

data_dir_file = '/home/ec2-user/TEST996.json' # ***THIS NEEDS TO BE CHANGED***

with open(data_dir_file) as fr:
    dataAPI = json.load(fr)

#
# Set some file name variables
#
# Set path_to_file to your installation directory
#

path_to_file = ('/home/ec2-user/') # ***THIS NEEDS TO BE CHANGED to your installation directory*** 
name_of_file = ('API_data.txt') # this is the file to which the sorted data is written
full_file = f'{path_to_file}{name_of_file}'

#
# Determine the number of observations to process
#

x = 0
for data in dataAPI['STATION']:
    if 'MINMAX' in data:
        pass 
    else:
        data['MINMAX'] = 'None'
                      
    x = x + 1 

print()    
print(f'There are {x} observations this hour')
print()
    
station = dataAPI['STATION']
y = 0 

with open(full_file, 'w') as outfile: 

    while (y < x):
      
        mnet_id = station[y]
        stid = mnet_id.get('STID')
        station_name = mnet_id.get('NAME')
        station_name = station_name.replace(',','')
        state = mnet_id.get('STATE')
        lat = mnet_id.get('LATITUDE')
        lon = mnet_id.get('LONGITUDE')
        el = mnet_id.get('ELEVATION')
        tz = mnet_id.get('TIMEZONE')
        temps_info = mnet_id.get('MINMAX')
        if temps_info == 'None':
            print(f'The air temperature information is missing for {stid}') 
            air_temps_info = 'None'
            dates = 'None'
            max_utc = 'None'
            min_utc = 'None'
            time_min_utc = 'None'
            time_max_utc = 'None'
            y +=1
            continue      
  
        air_temps_info = temps_info.get('air_temp_value_1')
        dates = air_temps_info.get('dates')
        dates = (''.join(dates))
        max_utc = air_temps_info.get('value_max_utc')
        max_utc = ("".join([str(i)for i in max_utc]))  
        min_utc = air_temps_info.get('value_min_utc')
        min_utc = ("".join([str(i)for i in min_utc]))
        time_min_utc = air_temps_info.get('datetime_min_utc')
        time_min_utc = (''.join(time_min_utc))
        time_max_utc = air_temps_info.get('datetime_max_utc')
        time_max_utc = (''.join(time_max_utc))
        
        print(f'{stid},{station_name},{state},{lat},{lon},{el},{tz},{dates},{min_utc},{time_min_utc},{max_utc},{time_max_utc}', file = outfile)
        y +=1    
       

print()        
print(f'Wrote {y} stations to {full_file}')
# Out:
# There are 4176 observations this hour
#
# The air temperature information is missing for KSLC
# The air temperature information is missing for KU42
# The air temperature information is missing for KHIF
# The air temperature information is missing for KOGD
# The air temperature information is missing for KBMC
# The air temperature information is missing for KPVU
# The air temperature information is missing for KLGU
# The air temperature information is missing for KPUC
# The air temperature information is missing for KVEL
# The air temperature information is missing for KGCD
# The air temperature information is missing for KAAT
# The air temperature information is missing for KABQ
# The air temperature information is missing for KACV
# The air temperature information is missing for KAEG
# The air temperature information is missing for KAFF
# The air temperature information is missing for KAKO
# The air temperature information is missing for KALM
# The air temperature information is missing for KALS
# The air temperature information is missing for KALW
# The air temperature information is missing for KAPA
# The air temperature information is missing for KAPC
# The air temperature information is missing for KASE
# The air temperature information is missing for KAST
# The air temperature information is missing for KATS
# The air temperature information is missing for KAWO
# The air temperature information is missing for KBAM
# The air temperature information is missing for KBAB
# The air temperature information is missing for KBCE
# The air temperature information is missing for KBDG
# The air temperature information is missing for KBFI
# The air temperature information is missing for KBFL
# The air temperature information is missing for KBHK
# The air temperature information is missing for KBIH
# The air temperature information is missing for KBIL
# The air temperature information is missing for KBJC
# The air temperature information is missing for KBKE
# The air temperature information is missing for KBLH
# The air temperature information is missing for KBLI
# The air temperature information is missing for KBLU
# The air temperature information is missing for KBNO
# The air temperature information is missing for KBOI
# The air temperature information is missing for KBPI
# The air temperature information is missing for KBTM
# The air temperature information is missing for KBUR
# The air temperature information is missing for KBYG
# The air temperature information is missing for KBYI
# The air temperature information is missing for KBYS
# The air temperature information is missing for KBZN
# The air temperature information is missing for KCAG
# The air temperature information is missing for KCAO
# The air temperature information is missing for KCCR
# The air temperature information is missing for KCDC
# The air temperature information is missing for KCEC
# The air temperature information is missing for KCEZ
# The air temperature information is missing for KCGZ
# The air temperature information is missing for KCLM
# The air temperature information is missing for KCMA
# The air temperature information is missing for KCNM
# The air temperature information is missing for KCNO
# The air temperature information is missing for KCNY
# The air temperature information is missing for KCOD
# The air temperature information is missing for KCOE
# The air temperature information is missing for KCOS
# The air temperature information is missing for KCPR
# The air temperature information is missing for KCQT
# The air temperature information is missing for KCRQ
# The air temperature information is missing for KCTB
# The air temperature information is missing for KCVN
# The air temperature information is missing for KCVO
# The air temperature information is missing for KCVS
# The air temperature information is missing for KCYS
# The air temperature information is missing for KDAG
# The air temperature information is missing for KDEN
# The air temperature information is missing for KDEW
# The air temperature information is missing for KDGW
# The air temperature information is missing for KDLN
# The air temperature information is missing for KDLS
# The air temperature information is missing for KDMA
# The air temperature information is missing for KDMN
# The air temperature information is missing for KDRA
# The air temperature information is missing for KDRO
# The air temperature information is missing for KDUG
# The air temperature information is missing for KDVT
# The air temperature information is missing for KEAT
# The air temperature information is missing for KEDW
# The air temperature information is missing for KEED
# The air temperature information is missing for KEEO
# The air temperature information is missing for KEGE
# The air temperature information is missing for KEKO
# The air temperature information is missing for KELN
# The air temperature information is missing for KELY
# The air temperature information is missing for KEMT
# The air temperature information is missing for KENV
# The air temperature information is missing for KEPH
# The air temperature information is missing for KEUG
# The air temperature information is missing for KFAT
# The air temperature information is missing for KFCS
# The air temperature information is missing for KFFZ
# The air temperature information is missing for KFHR
# The air temperature information is missing for KFHU
# The air temperature information is missing for KFLG
# The air temperature information is missing for KFMN
# The air temperature information is missing for KFNL
# The air temperature information is missing for KFUL
# The air temperature information is missing for KGCC
# The air temperature information is missing for KGCN
# The air temperature information is missing for KGDV
# The air temperature information is missing for KGEG
# The air temperature information is missing for KGEU
# The air temperature information is missing for KGFA
# The air temperature information is missing for KGGW
# The air temperature information is missing for KGJT
# The air temperature information is missing for KGNT
# The air temperature information is missing for KGRF
# The air temperature information is missing for KGTF
# The air temperature information is missing for KGUC
# The air temperature information is missing for KGUP
# The air temperature information is missing for KGXY
# The air temperature information is missing for KGYR
# The air temperature information is missing for KHDN
# The air temperature information is missing for KHHR
# The air temperature information is missing for KHIO
# The air temperature information is missing for KHJO
# The air temperature information is missing for KHLN
# The air temperature information is missing for KHMN
# The air temperature information is missing for KHOB
# The air temperature information is missing for KHQM
# The air temperature information is missing for KHRI
# The air temperature information is missing for KHVR
# The air temperature information is missing for KHWD
# The air temperature information is missing for KIDA
# The air temperature information is missing for KIFP
# The air temperature information is missing for KIGM
# The air temperature information is missing for KINW
# The air temperature information is missing for KIPL
# The air temperature information is missing for KITR
# The air temperature information is missing for KJAC
# The air temperature information is missing for KJDN
# The air temperature information is missing for KJER
# The air temperature information is missing for KKLS
# The air temperature information is missing for KLAA
# The air temperature information is missing for KLAM
# The air temperature information is missing for KLAR
# The air temperature information is missing for KLAS
# The air temperature information is missing for KLAX
# The air temperature information is missing for KLGB
# The air temperature information is missing for KLGD
# The air temperature information is missing for KLHX
# The air temperature information is missing for KLIC
# The air temperature information is missing for KLKV
# The air temperature information is missing for KLLJ
# The air temperature information is missing for KLMT
# The air temperature information is missing for KLND
# The air temperature information is missing for KLOL
# The air temperature information is missing for KLPC
# The air temperature information is missing for KLRU
# The air temperature information is missing for KLSV
# The air temperature information is missing for KLUF
# The air temperature information is missing for KLVK
# The air temperature information is missing for KLVM
# The air temperature information is missing for KLVS
# The air temperature information is missing for KLWS
# The air temperature information is missing for KLWT
# The air temperature information is missing for KLXV
# The air temperature information is missing for KMCC
# The air temperature information is missing for KMCE
# The air temperature information is missing for KMFR
# The air temperature information is missing for KMHR
# The air temperature information is missing for KMHS
# The air temperature information is missing for KMHV
# The air temperature information is missing for KMLF
# The air temperature information is missing for KMLP
# The air temperature information is missing for KMLS
# The air temperature information is missing for KMMH
# The air temperature information is missing for KMOD
# The air temperature information is missing for KMRY
# The air temperature information is missing for KMSO
# The air temperature information is missing for KMTJ
# The air temperature information is missing for KMUO
# The air temperature information is missing for KMWH
# The air temperature information is missing for KMYF
# The air temperature information is missing for KMYL
# The air temperature information is missing for KNFG
# The air temperature information is missing for KNFL
# The air temperature information is missing for KNID
# The air temperature information is missing for KNJK
# The air temperature information is missing for KNKX
# The air temperature information is missing for KNLC
# The air temperature information is missing for KNSI
# The air temperature information is missing for KNTD
# The air temperature information is missing for KNUC
# The air temperature information is missing for KNUQ
# The air temperature information is missing for KNUW
# The air temperature information is missing for KNXP
# The air temperature information is missing for KNZY
# The air temperature information is missing for KOAK
# The air temperature information is missing for KOAR
# The air temperature information is missing for KOKB
# The air temperature information is missing for KOLF
# The air temperature information is missing for KOLM
# The air temperature information is missing for KOLS
# The air temperature information is missing for KONO
# The air temperature information is missing for KONP
# The air temperature information is missing for KONT
# The air temperature information is missing for KOTH
# The air temperature information is missing for KOVE
# The air temperature information is missing for KOXR
# The air temperature information is missing for KP60
# The air temperature information is missing for KP68
# The air temperature information is missing for KP69
# The air temperature information is missing for KPAE
# The air temperature information is missing for KPDT
# The air temperature information is missing for KPDX
# The air temperature information is missing for KPGA
# The air temperature information is missing for KPHX
# The air temperature information is missing for KPIH
# The air temperature information is missing for KPRB
# The air temperature information is missing for KPRC
# The air temperature information is missing for KPSC
# The air temperature information is missing for KPSP
# The air temperature information is missing for KPTV
# The air temperature information is missing for KPUB
# The air temperature information is missing for KPUW
# The air temperature information is missing for KPWT
# The air temperature information is missing for KRAL
# The air temperature information is missing for KRBL
# The air temperature information is missing for KRBG
# The air temperature information is missing for KRDD
# The air temperature information is missing for KRDM
# The air temperature information is missing for KREO
# The air temperature information is missing for KRHV
# The air temperature information is missing for KRIL
# The air temperature information is missing for KRIV
# The air temperature information is missing for KRIW
# The air temperature information is missing for KRKS
# The air temperature information is missing for KRNM
# The air temperature information is missing for KRNO
# The air temperature information is missing for KRNT
# The air temperature information is missing for KROW
# The air temperature information is missing for KRQE
# The air temperature information is missing for KRTN
# The air temperature information is missing for KRWL
# The air temperature information is missing for KRXE
# The air temperature information is missing for KGIC
# The air temperature information is missing for KSAC
# The air temperature information is missing for KSAD
# The air temperature information is missing for KSAF
# The air temperature information is missing for KSAN
# The air temperature information is missing for KSBA
# The air temperature information is missing for KSBP
# The air temperature information is missing for KSBS
# The air temperature information is missing for KSCK
# The air temperature information is missing for KSDB
# The air temperature information is missing for KSDL
# The air temperature information is missing for KSDM
# The air temperature information is missing for KSDY
# The air temperature information is missing for KSEA
# The air temperature information is missing for KSEE
# The air temperature information is missing for KSFF
# The air temperature information is missing for KSFO
# The air temperature information is missing for KSGU
# The air temperature information is missing for KSHN
# The air temperature information is missing for KSHR
# The air temperature information is missing for KSIY
# The air temperature information is missing for KSJC
# The air temperature information is missing for KSKX
# The air temperature information is missing for KSLE
# The air temperature information is missing for KSLI
# The air temperature information is missing for KSMF
# The air temperature information is missing for KSMN
# The air temperature information is missing for KSMO
# The air temperature information is missing for KSMX
# The air temperature information is missing for KSNA
# The air temperature information is missing for KSNS
# The air temperature information is missing for KSNT
# The air temperature information is missing for KSOW
# The air temperature information is missing for KSPD
# The air temperature information is missing for KSQL
# The air temperature information is missing for KSRR
# The air temperature information is missing for KSTS
# The air temperature information is missing for KSUU
# The air temperature information is missing for KSVC
# The air temperature information is missing for KSVE
# The air temperature information is missing for KSXT
# The air temperature information is missing for KTAD
# The air temperature information is missing for KTCC
# The air temperature information is missing for KTCM
# The air temperature information is missing for KTCS
# The air temperature information is missing for KTEX
# The air temperature information is missing for KTIW
# The air temperature information is missing for KTOA
# The air temperature information is missing for KTPH
# The air temperature information is missing for KTRK
# The air temperature information is missing for KTRM
# The air temperature information is missing for KTTD
# The air temperature information is missing for KTUS
# The air temperature information is missing for KTVL
# The air temperature information is missing for KTWF
# The air temperature information is missing for KUAO
# The air temperature information is missing for KUIL
# The air temperature information is missing for KUKI
# The air temperature information is missing for KVCB
# The air temperature information is missing for KVGT
# The air temperature information is missing for KVIS
# The air temperature information is missing for KVNY
# The air temperature information is missing for KVUO
# The air temperature information is missing for KWJF
# The air temperature information is missing for KWRL
# The air temperature information is missing for KYKM
# The air temperature information is missing for KPWD
# The air temperature information is missing for KMLT
# The air temperature information is missing for KTOR
# The air temperature information is missing for KEVW
# The air temperature information is missing for KGEY
# The air temperature information is missing for NWRU1
# The air temperature information is missing for QBHA3
# The air temperature information is missing for QBRA3
# The air temperature information is missing for QBAA3
# The air temperature information is missing for QBMA3
# The air temperature information is missing for CHEA3
# The air temperature information is missing for QCGA3
# The air temperature information is missing for QCKA3
# The air temperature information is missing for QDLA3
# The air temperature information is missing for QDPA3
# The air temperature information is missing for QEMA3
# The air temperature information is missing for QFSA3
# The air temperature information is missing for QGDA3
# The air temperature information is missing for QGRA3
# The air temperature information is missing for QGSA3
# The air temperature information is missing for QGTA3
# The air temperature information is missing for QHAA3
# The air temperature information is missing for QCHA3
# The air temperature information is missing for QHRA3
# The air temperature information is missing for QHBA3
# The air temperature information is missing for QHUA3
# The air temperature information is missing for QLCA3
# The air temperature information is missing for QLBA3
# The air temperature information is missing for QMBA3
# The air temperature information is missing for QMLA3
# The air temperature information is missing for QMRA3
# The air temperature information is missing for QMMA3
# The air temperature information is missing for QOCA3
# The air temperature information is missing for QOKA3
# The air temperature information is missing for QPAA3
# The air temperature information is missing for QPRA3
# The air temperature information is missing for QHVA3
# The air temperature information is missing for TTBA3
# The air temperature information is missing for QSBA3
# The air temperature information is missing for QHQA3
# The air temperature information is missing for QSTA3
# The air temperature information is missing for QSPA3
# The air temperature information is missing for QTCA3
# The air temperature information is missing for QTWA3
# The air temperature information is missing for QUPA3
# The air temperature information is missing for QVDA3
# The air temperature information is missing for QWSA3
# The air temperature information is missing for QYJA3
# The air temperature information is missing for ATNC1
# The air temperature information is missing for ALDC1
# The air temperature information is missing for ECKC1
# The air temperature information is missing for NZAC1
# The air temperature information is missing for ARGC1
# The air temperature information is missing for ASRC1
# The air temperature information is missing for BDMC1
# The air temperature information is missing for BNGC1
# The air temperature information is missing for BBEC1
# The air temperature information is missing for BPKC1
# The air temperature information is missing for COKC1
# The air temperature information is missing for CAPC1
# The air temperature information is missing for BNDC1
# The air temperature information is missing for BVRC1
# The air temperature information is missing for BGBC1
# The air temperature information is missing for PIBC1
# The air temperature information is missing for BNVC1
# The air temperature information is missing for BRHC1
# The air temperature information is missing for BZRC1
# The air temperature information is missing for PLEC1
# The air temperature information is missing for BUFC1
# The air temperature information is missing for BCNC1
# The air temperature information is missing for PEAC1
# The air temperature information is missing for CLNC1
# The air temperature information is missing for CMNC1
# The air temperature information is missing for CNIC1
# The air temperature information is missing for CSPC1
# The air temperature information is missing for SMTM8
# The air temperature information is missing for CEEC1
# The air temperature information is missing for CESC1
# The air temperature information is missing for CICC1
# The air temperature information is missing for CUUC1
# The air temperature information is missing for CMOC1
# The air temperature information is missing for CSTC1
# The air temperature information is missing for CVEC1
# The air temperature information is missing for CRGC1
# The air temperature information is missing for CTOC1
# The air temperature information is missing for WISC1
# The air temperature information is missing for CRZC1
# The air temperature information is missing for CRVC1
# The air temperature information is missing for DLVC1
# The air temperature information is missing for DENC1
# The air temperature information is missing for ATSC1
# The air temperature information is missing for DVOC1
# The air temperature information is missing for RRRC1
# The air temperature information is missing for DYLC1
# The air temperature information is missing for EELC1
# The air temperature information is missing for ECSC1
# The air temperature information is missing for EMRC1
# The air temperature information is missing for ESPC1
# The air temperature information is missing for FWSC1
# The air temperature information is missing for FHCC1
# The air temperature information is missing for FRCC1
# The air temperature information is missing for FMOC1
# The air temperature information is missing for GNTC1
# The air temperature information is missing for GRSC1
# The air temperature information is missing for GNSC1
# The air temperature information is missing for CAHC1
# The air temperature information is missing for HLLC1
# The air temperature information is missing for HDZC1
# The air temperature information is missing for HGLC1
# The air temperature information is missing for HLKC1
# The air temperature information is missing for HTSC1
# The air temperature information is missing for HTRC1
# The air temperature information is missing for JWBC1
# The air temperature information is missing for JTAC1
# The air temperature information is missing for JULC1
# The air temperature information is missing for JPRC1
# The air temperature information is missing for KNWC1
# The air temperature information is missing for KTLC1
# The air temperature information is missing for KNXC1
# The air temperature information is missing for LAHC1
# The air temperature information is missing for LPZC1
# The air temperature information is missing for LDRC1
# The air temperature information is missing for TABC1
# The air temperature information is missing for LTRC1
# The air temperature information is missing for LSNC1
# The air temperature information is missing for LICC1
# The air temperature information is missing for LOAC1
# The air temperature information is missing for SLRC1
# The air temperature information is missing for LSGC1
# The air temperature information is missing for LPOC1
# The air temperature information is missing for COWC1
# The air temperature information is missing for LVMC1
# The air temperature information is missing for VIOC1
# The air temperature information is missing for MPOC1
# The air temperature information is missing for MKEC1
# The air temperature information is missing for MDHC1
# The air temperature information is missing for MLCC1
# The air temperature information is missing for MMKC1
# The air temperature information is missing for BIJC1
# The air temperature information is missing for MTIC1
# The air temperature information is missing for MLGC1
# The air temperature information is missing for IDPC1
# The air temperature information is missing for OGVC1
# The air temperature information is missing for OKNC1
# The air temperature information is missing for OMTC1
# The air temperature information is missing for ONOC1
# The air temperature information is missing for OKSC1
# The air temperature information is missing for OPLC1
# The air temperature information is missing for OWNC1
# The air temperature information is missing for PCEC1
# The air temperature information is missing for PMCC1
# The air temperature information is missing for PIEC1
# The air temperature information is missing for PKCC1
# The air temperature information is missing for POTC1
# The air temperature information is missing for MIPC1
# The air temperature information is missing for PUGC1
# The air temperature information is missing for QTZC1
# The air temperature information is missing for QYRC1
# The air temperature information is missing for RCHC1
# The air temperature information is missing for RVYC1
# The air temperature information is missing for RSPC1
# The air temperature information is missing for ROVC1
# The air temperature information is missing for RNDC1
# The air temperature information is missing for SBIC1
# The air temperature information is missing for SNCC1
# The air temperature information is missing for RSAC1
# The air temperature information is missing for SRIC1
# The air temperature information is missing for SRUC1
# The air temperature information is missing for SWBC1
# The air temperature information is missing for CFCC1
# The air temperature information is missing for SETC1
# The air temperature information is missing for SMSC1
# The air temperature information is missing for ATRC1
# The air temperature information is missing for SOAC1
# The air temperature information is missing for SDRC1
# The air temperature information is missing for SMBC1
# The air temperature information is missing for HSPC1
# The air temperature information is missing for SQSC1
# The air temperature information is missing for SMDC1
# The air temperature information is missing for TANC1
# The air temperature information is missing for TCKC1
# The air temperature information is missing for DBLN2
# The air temperature information is missing for TCAC1
# The air temperature information is missing for VLCC1
# The air temperature information is missing for VABC1
# The air temperature information is missing for WMSC1
# The air temperature information is missing for WEEC1
# The air temperature information is missing for CISC1
# The air temperature information is missing for WITC1
# The air temperature information is missing for WVTC1
# The air temperature information is missing for WWRC1
# The air temperature information is missing for YOBC1
# The air temperature information is missing for CPTC2
# The air temperature information is missing for CHAC2
# The air temperature information is missing for CHRC2
# The air temperature information is missing for CGRC2
# The air temperature information is missing for CMEC2
# The air temperature information is missing for DMMC2
# The air temperature information is missing for SURC2
# The air temperature information is missing for DRAC2
# The air temperature information is missing for GDRC2
# The air temperature information is missing for GSPC2
# The air temperature information is missing for GPRC2
# The air temperature information is missing for HCKC2
# The air temperature information is missing for HMEC2
# The air temperature information is missing for JCRC2
# The air temperature information is missing for JAYC2
# The air temperature information is missing for LODC2
# The air temperature information is missing for LKGC2
# The air temperature information is missing for LDRC2
# The air temperature information is missing for MMRC2
# The air temperature information is missing for PNRC2
# The air temperature information is missing for CCEC2
# The air temperature information is missing for PIRC2
# The air temperature information is missing for RDKC2
# The air temperature information is missing for RFRC2
# The air temperature information is missing for RFEC2
# The air temperature information is missing for SAWC2
# The air temperature information is missing for SDVC2
# The air temperature information is missing for SPKC2
# The air temperature information is missing for CRWC2
# The air temperature information is missing for WICC2
# The air temperature information is missing for ACRI1
# The air temperature information is missing for BCFI1
# The air temperature information is missing for YFFI1
# The air temperature information is missing for BULI1
# The air temperature information is missing for CHRI1
# The air temperature information is missing for DYGC2
# The air temperature information is missing for CBFI1
# The air temperature information is missing for CYFI1
# The air temperature information is missing for DEAI1
# The air temperature information is missing for DPKI1
# The air temperature information is missing for DEHI1
# The air temperature information is missing for DNFI1
# The air temperature information is missing for DMNI1
# The air temperature information is missing for EZRI1
# The air temperature information is missing for FERI1
# The air temperature information is missing for FHFI1
# The air temperature information is missing for FLEI1
# The air temperature information is missing for FLFI1
# The air temperature information is missing for GASI1
# The air temperature information is missing for GSKI1
# The air temperature information is missing for GRAI1
# The air temperature information is missing for HBFI1
# The air temperature information is missing for HPFI1
# The air temperature information is missing for INDI1
# The air temperature information is missing for KELI1
# The air temperature information is missing for KRCI1
# The air temperature information is missing for LDOI1
# The air temperature information is missing for LTAI1
# The air temperature information is missing for THFI1
# The air temperature information is missing for LPFI1
# The air temperature information is missing for MOFI1
# The air temperature information is missing for MYFI1
# The air temperature information is missing for MOOI1
# The air temperature information is missing for OHOI1
# The air temperature information is missing for PIEI1
# The air temperature information is missing for PNFI1
# The air temperature information is missing for PLFI1
# The air temperature information is missing for PCNI1
# The air temperature information is missing for PCKI1
# The air temperature information is missing for POTI1
# The air temperature information is missing for PBUI1
# The air temperature information is missing for RFTI1
# The air temperature information is missing for RRFI1
# The air temperature information is missing for ROCI1
# The air temperature information is missing for SADI1
# The air temperature information is missing for SMYI1
# The air temperature information is missing for SHCI1
# The air temperature information is missing for SKFI1
# The air temperature information is missing for SCFI1
# The air temperature information is missing for SRFI1
# The air temperature information is missing for MCLI1
# The air temperature information is missing for TCFI1
# The air temperature information is missing for TGFI1
# The air temperature information is missing for TRII1
# The air temperature information is missing for TWBI1
# The air temperature information is missing for WEFI1
# The air temperature information is missing for ARMM8
# The air temperature information is missing for BAFM8
# The air temperature information is missing for BIFM8
# The air temperature information is missing for BEFM8
# The air temperature information is missing for LCFM8
# The air temperature information is missing for BHMM8
# The air temperature information is missing for BLUM8
# The air temperature information is missing for BSHM8
# The air temperature information is missing for BRRM8
# The air temperature information is missing for BRTM8
# The air temperature information is missing for CACM8
# The air temperature information is missing for CYFM8
# The air temperature information is missing for DBCM8
# The air temperature information is missing for FSLM8
# The air temperature information is missing for FBLM8
# The air temperature information is missing for FHFM8
# The air temperature information is missing for GAAM8
# The air temperature information is missing for GINM8
# The air temperature information is missing for HOTM8
# The air temperature information is missing for JETM8
# The air temperature information is missing for KIGM8
# The air temperature information is missing for KTFM8
# The air temperature information is missing for LBCM8
# The air temperature information is missing for MCDM8
# The air temperature information is missing for PNHM8
# The air temperature information is missing for POPM8
# The air temperature information is missing for PMRM8
# The air temperature information is missing for RRDM8
# The air temperature information is missing for RCBM8
# The air temperature information is missing for SSMM8
# The air temperature information is missing for SPOM8
# The air temperature information is missing for SRYM8
# The air temperature information is missing for WWMM8
# The air temperature information is missing for ALDM8
# The air temperature information is missing for CWRN5
# The air temperature information is missing for BATN5
# The air temperature information is missing for MGNN5
# The air temperature information is missing for BDAN5
# The air temperature information is missing for ACON5
# The air temperature information is missing for CPPN5
# The air temperature information is missing for BCHN5
# The air temperature information is missing for COYN5
# The air temperature information is missing for CBBN5
# The air temperature information is missing for LOMN5
# The air temperature information is missing for DUNN5
# The air temperature information is missing for REMN5
# The air temperature information is missing for GNMN5
# The air temperature information is missing for HHRN5
# The air temperature information is missing for TS053
# The air temperature information is missing for GMLN5
# The air temperature information is missing for MPAN5
# The air temperature information is missing for LVPN5
# The air temperature information is missing for DPRN5
# The air temperature information is missing for SNDN5
# The air temperature information is missing for MCRN5
# The air temperature information is missing for SLMN5
# The air temperature information is missing for ALLN2
# The air temperature information is missing for ALRN2
# The air temperature information is missing for BATN2
# The air temperature information is missing for BLUN2
# The air temperature information is missing for CYVN2
# The air temperature information is missing for CATN2
# The air temperature information is missing for CTLN2
# The air temperature information is missing for CEDN2
# The air temperature information is missing for COIN2
# The air temperature information is missing for COMN2
# The air temperature information is missing for COYN2
# The air temperature information is missing for CRSN2
# The air temperature information is missing for CCRN2
# The air temperature information is missing for DEDN2
# The air temperature information is missing for GRVN2
# The air temperature information is missing for DESN2
# The air temperature information is missing for DRYN2
# The air temperature information is missing for FISN2
# The air temperature information is missing for FOXN2
# The air temperature information is missing for IMWN2
# The air temperature information is missing for JSPN2
# The air temperature information is missing for KNSN2
# The air temperature information is missing for KYCN2
# The air temperature information is missing for LONN2
# The air temperature information is missing for MTHN2
# The air temperature information is missing for MORN2
# The air temperature information is missing for PANN2
# The air temperature information is missing for RBTN2
# The air temperature information is missing for RRKN2
# The air temperature information is missing for RSCN2
# The air temperature information is missing for SIAN2
# The air temperature information is missing for SPGN2
# The air temperature information is missing for SPMN2
# The air temperature information is missing for STMN2
# The air temperature information is missing for TEXN2
# The air temperature information is missing for MJBN2
# The air temperature information is missing for AGFO3
# The air temperature information is missing for ALFO3
# The air temperature information is missing for ATFO3
# The air temperature information is missing for BGFO3
# The air temperature information is missing for BKFO3
# The air temperature information is missing for BAFO3
# The air temperature information is missing for BQFO3
# The air temperature information is missing for OKFO3
# The air temperature information is missing for BYFO3
# The air temperature information is missing for BCFO3
# The air temperature information is missing for IRFO3
# The air temperature information is missing for BWFO3
# The air temperature information is missing for BRUO3
# The air temperature information is missing for PKFO3
# The air temperature information is missing for BUCO3
# The air temperature information is missing for BNFO3
# The air temperature information is missing for CAFO3
# The air temperature information is missing for CVFO3
# The air temperature information is missing for TPEO3
# The air temperature information is missing for CNFO3
# The air temperature information is missing for CEFO3
# The air temperature information is missing for CDFO3
# The air temperature information is missing for LBJT2
# The air temperature information is missing for CIFO3
# The air temperature information is missing for PTFO3
# The air temperature information is missing for CSFO3
# The air temperature information is missing for CGFO3
# The air temperature information is missing for CPFO3
# The air temperature information is missing for CWFO3
# The air temperature information is missing for ENFO3
# The air temperature information is missing for EMFO3
# The air temperature information is missing for FMFO3
# The air temperature information is missing for FEFO3
# The air temperature information is missing for FFFO3
# The air temperature information is missing for FAFO3
# The air temperature information is missing for FKFO3
# The air temperature information is missing for GRBO3
# The air temperature information is missing for GPFO3
# The air temperature information is missing for GDFO3
# The air temperature information is missing for GSFO3
# The air temperature information is missing for WWCO3
# The air temperature information is missing for HYFO3
# The air temperature information is missing for HHFO3
# The air temperature information is missing for LOFO3
# The air temperature information is missing for HSFO3
# The air temperature information is missing for OYFO3
# The air temperature information is missing for SBFO3
# The air temperature information is missing for JRFO3
# The air temperature information is missing for KEEO3
# The air temperature information is missing for KBFO3
# The air temperature information is missing for LBFO3
# The air temperature information is missing for LGFO3
# The air temperature information is missing for MEFO3
# The air temperature information is missing for MGFO3
# The air temperature information is missing for MSFO3
# The air temperature information is missing for WSFO3
# The air temperature information is missing for MMFO3
# The air temperature information is missing for NPFO3
# The air temperature information is missing for OMFO3
# The air temperature information is missing for OWFO3
# The air temperature information is missing for FGFO3
# The air temperature information is missing for ARFO3
# The air temperature information is missing for PAFO3
# The air temperature information is missing for PEFO3
# The air temperature information is missing for PPFO3
# The air temperature information is missing for PYFO3
# The air temperature information is missing for QPFO3
# The air temperature information is missing for RXFO3
# The air temperature information is missing for RTFO3
# The air temperature information is missing for RMFO3
# The air temperature information is missing for RLFO3
# The air temperature information is missing for RCRO3
# The air temperature information is missing for RNFO3
# The air temperature information is missing for BDFO3
# The air temperature information is missing for SHFO3
# The air temperature information is missing for SLTO3
# The air temperature information is missing for SDFO3
# The air temperature information is missing for TRFO3
# The air temperature information is missing for SVFO3
# The air temperature information is missing for SLFO3
# The air temperature information is missing for SAFO3
# The air temperature information is missing for SQFO3
# The air temperature information is missing for STFO3
# The air temperature information is missing for SGFO3
# The air temperature information is missing for SMFO3
# The air temperature information is missing for TMFO3
# The air temperature information is missing for TOFO3
# The air temperature information is missing for TCFO3
# The air temperature information is missing for TUFO3
# The air temperature information is missing for VCFO3
# The air temperature information is missing for WTFO3
# The air temperature information is missing for WMFO3
# The air temperature information is missing for YEFO3
# The air temperature information is missing for BBFO3
# The air temperature information is missing for ACRU1
# The air temperature information is missing for ASYU1
# The air temperature information is missing for BADU1
# The air temperature information is missing for BIVU1
# The air temperature information is missing for BKCU1
# The air temperature information is missing for BSTU1
# The air temperature information is missing for BRPU1
# The air temperature information is missing for BCRU1
# The air temperature information is missing for BUKU1
# The air temperature information is missing for BEUU1
# The air temperature information is missing for CCRU1
# The air temperature information is missing for DIAU1
# The air temperature information is missing for FIVU1
# The air temperature information is missing for FTMU1
# The air temperature information is missing for HWAU1
# The air temperature information is missing for HOHU1
# The air temperature information is missing for HSRU1
# The air temperature information is missing for JSPU1
# The air temperature information is missing for JVAU1
# The air temperature information is missing for KAGU1
# The air temperature information is missing for KPRU1
# The air temperature information is missing for LPRU1
# The air temperature information is missing for LSCU1
# The air temperature information is missing for MCKU1
# The air temperature information is missing for MSRU1
# The air temperature information is missing for SBWU1
# The air temperature information is missing for SIGU1
# The air temperature information is missing for TBSU1
# The air temperature information is missing for TVWU1
# The air temperature information is missing for UPRU1
# The air temperature information is missing for USWU1
# The air temperature information is missing for VENU1
# The air temperature information is missing for WRRU1
# The air temperature information is missing for WHBU1
# The air temperature information is missing for WNTU1
# The air temperature information is missing for SFLU1
# The air temperature information is missing for YLSU1
# The air temperature information is missing for ABNW1
# The air temperature information is missing for ADFW1
# The air temperature information is missing for CMFW1
# The air temperature information is missing for CYFW1
# The air temperature information is missing for BSCA4
# The air temperature information is missing for CGFW1
# The air temperature information is missing for DOUW1
# The air temperature information is missing for DIFW1
# The air temperature information is missing for DRYW1
# The air temperature information is missing for FIFW1
# The air temperature information is missing for FBFW1
# The air temperature information is missing for FTFW1
# The air temperature information is missing for GHFW1
# The air temperature information is missing for GMFW1
# The air temperature information is missing for GRFW1
# The air temperature information is missing for HGFW1
# The air temperature information is missing for HKFW1
# The air temperature information is missing for HUFW1
# The air temperature information is missing for HURW1
# The air temperature information is missing for JEFW1
# The air temperature information is missing for SKKW1
# The air temperature information is missing for JUFW1
# The air temperature information is missing for KTLW1
# The air temperature information is missing for KCFW1
# The air temperature information is missing for KOSW1
# The air temperature information is missing for KMFW1
# The air temperature information is missing for LEFW1
# The air temperature information is missing for LSFW1
# The air temperature information is missing for LLFW1
# The air temperature information is missing for NCSW1
# The air temperature information is missing for OVLW1
# The air temperature information is missing for OCFW1
# The air temperature information is missing for PMFW1
# The air temperature information is missing for PEFW1
# The air temperature information is missing for PEOW1
# The air temperature information is missing for QCNW1
# The air temperature information is missing for MEFW1
# The air temperature information is missing for PIFW1
# The air temperature information is missing for SMFW1
# The air temperature information is missing for FWFW1
# The air temperature information is missing for TCFW1
# The air temperature information is missing for TPFW1
# The air temperature information is missing for FTAW1
# The air temperature information is missing for BKRW1
# The air temperature information is missing for VPFW1
# The air temperature information is missing for ANDW4
# The air temperature information is missing for BUJW4
# The air temperature information is missing for ERAW4
# The air temperature information is missing for CAMW4
# The air temperature information is missing for CMRW4
# The air temperature information is missing for COWW4
# The air temperature information is missing for CDAW4
# The air temperature information is missing for DODW4
# The air temperature information is missing for ECEW4
# The air temperature information is missing for RSNW4
# The air temperature information is missing for GCRW4
# The air temperature information is missing for HAFW4
# The air temperature information is missing for HOBW4
# The air temperature information is missing for HHRW4
# The air temperature information is missing for MUDW4
# The air temperature information is missing for PCRW4
# The air temperature information is missing for QADW4
# The air temperature information is missing for RASW4
# The air temperature information is missing for RATW4
# The air temperature information is missing for RHKW4
# The air temperature information is missing for SAWW4
# The air temperature information is missing for SPKW4
# The air temperature information is missing for BPYW4
# The air temperature information is missing for SNOW4
# The air temperature information is missing for SPLW4
# The air temperature information is missing for THRW4
# The air temperature information is missing for WRVW4
# The air temperature information is missing for WPKO3
# The air temperature information is missing for RVZU1
# The air temperature information is missing for KOMK
# The air temperature information is missing for KMMV
# The air temperature information is missing for KTMK
# The air temperature information is missing for KSPB
# The air temperature information is missing for KS21
# The air temperature information is missing for ALRA3
# The air temperature information is missing for QNOA3
# The air temperature information is missing for FZWA3
# The air temperature information is missing for QHEA3
# The air temperature information is missing for QSLA3
# The air temperature information is missing for QGBA3
# The air temperature information is missing for DPMC1
# The air temperature information is missing for EKIM8
# The air temperature information is missing for BKRC1
# The air temperature information is missing for HDVC1
# The air temperature information is missing for QCAC1
# The air temperature information is missing for EDRC1
# The air temperature information is missing for CLHC1
# The air temperature information is missing for CLBC1
# The air temperature information is missing for EPKC1
# The air temperature information is missing for FMRC1
# The air temperature information is missing for BMUC1
# The air temperature information is missing for HYFC1
# The air temperature information is missing for IDWC1
# The air temperature information is missing for IWLC1
# The air temperature information is missing for JSNC1
# ...
# The air temperature information is missing for TT441
# The air temperature information is missing for TT442
# The air temperature information is missing for TT443
# The air temperature information is missing for KFYE
# The air temperature information is missing for KCXW
# The air temperature information is missing for KRID
# The air temperature information is missing for KKY8
# The air temperature information is missing for KSXU
# The air temperature information is missing for KI23
# The air temperature information is missing for KBEC
# The air temperature information is missing for K19S
# The air temperature information is missing for K6P9
# The air temperature information is missing for KETN
# The air temperature information is missing for CRWM7
# The air temperature information is missing for K2A0
# The air temperature information is missing for KMNV
# The air temperature information is missing for TT448
# The air temperature information is missing for KWYC1
# The air temperature information is missing for TT453
# The air temperature information is missing for K4R5
# The air temperature information is missing for TT456
# The air temperature information is missing for RUNP1
# The air temperature information is missing for BNJC1
# The air temperature information is missing for KDNA
# The air temperature information is missing for K8A3
# The air temperature information is missing for LDEC1
# The air temperature information is missing for MNMC1
# The air temperature information is missing for TT467
# The air temperature information is missing for TT469
# The air temperature information is missing for TT470
# The air temperature information is missing for UCL01
# The air temperature information is missing for UCL02
# The air temperature information is missing for UCL03
# The air temperature information is missing for UCL04
# The air temperature information is missing for UCL12
# The air temperature information is missing for UCL13
# The air temperature information is missing for UCL14
# The air temperature information is missing for UCL15
# The air temperature information is missing for UCL16
# The air temperature information is missing for UCL17
# The air temperature information is missing for UCL18
# The air temperature information is missing for UCL19
# The air temperature information is missing for UCL20
# The air temperature information is missing for UCL21
# The air temperature information is missing for UCL22
# The air temperature information is missing for UCL23
# The air temperature information is missing for UCL24
# The air temperature information is missing for UCL25
# The air temperature information is missing for UCL26
# The air temperature information is missing for UCL27
# The air temperature information is missing for UCL28
# The air temperature information is missing for UCL29
# The air temperature information is missing for UCL30
# The air temperature information is missing for DRBS1
# The air temperature information is missing for TT478
# The air temperature information is missing for TBLS1
# The air temperature information is missing for TT480
# The air temperature information is missing for TT482
# The air temperature information is missing for TT483
# The air temperature information is missing for KHLB
# The air temperature information is missing for SFPL1
# The air temperature information is missing for KVBW
# The air temperature information is missing for KTGI
# The air temperature information is missing for KLUV
# The air temperature information is missing for JCWT2
# The air temperature information is missing for RHBT2
# The air temperature information is missing for LATT2
# The air temperature information is missing for TT491
# The air temperature information is missing for MTRN1
# The air temperature information is missing for MKVN1
# The air temperature information is missing for KXNO
# The air temperature information is missing for FBZC1
# The air temperature information is missing for TT496
# The air temperature information is missing for K27K
# The air temperature information is missing for KBRY
# The air temperature information is missing for KFRH
# The air temperature information is missing for WSBN2
# The air temperature information is missing for KOYM
# The air temperature information is missing for KGNB
# The air temperature information is missing for K17J
# The air temperature information is missing for KD73
# The air temperature information is missing for K2J3
# The air temperature information is missing for TT498
# The air temperature information is missing for KRYM
# The air temperature information is missing for K1DW
# The air temperature information is missing for K1IW
# The air temperature information is missing for K1JW
# The air temperature information is missing for KRKW
# The air temperature information is missing for KLUG
# The air temperature information is missing for KM54
# The air temperature information is missing for KMBT
# The air temperature information is missing for KGCY
# The air temperature information is missing for KHPT
# The air temperature information is missing for KM02
# The air temperature information is missing for KPMH
# The air temperature information is missing for KX07
# The air temperature information is missing for GMRC1
# The air temperature information is missing for BCFC2
# The air temperature information is missing for TT509
# The air temperature information is missing for KGVQ
# The air temperature information is missing for TT510
# The air temperature information is missing for K2M2
# The air temperature information is missing for K1AW
# The air temperature information is missing for K1BW
# The air temperature information is missing for KL52
# The air temperature information is missing for KAAS
# The air temperature information is missing for KC83
# The air temperature information is missing for KO32
# The air temperature information is missing for SFXN5
# The air temperature information is missing for K06C
# The air temperature information is missing for KL08
# The air temperature information is missing for KLYO
# The air temperature information is missing for KEZZ
# The air temperature information is missing for K1MW
# The air temperature information is missing for TT530
# The air temperature information is missing for TT531
# The air temperature information is missing for KOXD
# The air temperature information is missing for TT532
# The air temperature information is missing for TT535
# The air temperature information is missing for KCCB
# The air temperature information is missing for KDLO
# The air temperature information is missing for KLGF
# The air temperature information is missing for KTCY
# The air temperature information is missing for KDSF
# The air temperature information is missing for KS52
# The air temperature information is missing for K7N0
# The air temperature information is missing for KC65
# The air temperature information is missing for KSUZ
# The air temperature information is missing for CXPC1
# The air temperature information is missing for KOIN
# The air temperature information is missing for TT542
# The air temperature information is missing for TT543
# The air temperature information is missing for K1GM
# The air temperature information is missing for KBWW
# The air temperature information is missing for KHSD
# The air temperature information is missing for MPVN2
# The air temperature information is missing for KJVY
# The air temperature information is missing for KTYL
# The air temperature information is missing for KTMT
# The air temperature information is missing for KI74
# The air temperature information is missing for K48A
# The air temperature information is missing for K2J5
# The air temperature information is missing for CUVC1
# The air temperature information is missing for FSGG1
# The air temperature information is missing for FSLG1
# The air temperature information is missing for FSPG1
# The air temperature information is missing for FSRG1
# The air temperature information is missing for FSTG1
# The air temperature information is missing for PUSC1
# The air temperature information is missing for K1DM
# The air temperature information is missing for TT561
# The air temperature information is missing for TT562
# The air temperature information is missing for TT563
# The air temperature information is missing for TT564
# The air temperature information is missing for TT565
# The air temperature information is missing for TT566
# The air temperature information is missing for TT567
# The air temperature information is missing for TT568
# The air temperature information is missing for TT569
# The air temperature information is missing for EGLW3
# The air temperature information is missing for TT571
# The air temperature information is missing for SRPW3
# The air temperature information is missing for LSRW3
# The air temperature information is missing for K33N
# The air temperature information is missing for K1KM
# The air temperature information is missing for K1LM
# The air temperature information is missing for K1AM
# The air temperature information is missing for K1BM
# The air temperature information is missing for K1CM
# The air temperature information is missing for K1FM
# The air temperature information is missing for K1IM
# The air temperature information is missing for K1MM
# The air temperature information is missing for K1NM
# The air temperature information is missing for K1OM
# The air temperature information is missing for TT575
# The air temperature information is missing for TT576
# The air temperature information is missing for TT578
# The air temperature information is missing for HRMC1
# The air temperature information is missing for MLXC1
# The air temperature information is missing for KH71
# The air temperature information is missing for KSXK
# The air temperature information is missing for KVNW
# The air temperature information is missing for KSCX
# The air temperature information is missing for TT582
# The air temperature information is missing for KSEQ
# The air temperature information is missing for KS85
# The air temperature information is missing for SFRS2
# The air temperature information is missing for TT584
# The air temperature information is missing for K77S
# The air temperature information is missing for TT587
# The air temperature information is missing for RLNM5
# The air temperature information is missing for K1CW
# The air temperature information is missing for K1EW
# The air temperature information is missing for K1HW
# The air temperature information is missing for TT592
# The air temperature information is missing for TT594
# The air temperature information is missing for TT595
# The air temperature information is missing for DOLP1
# The air temperature information is missing for BKBP1
# The air temperature information is missing for TT598
# The air temperature information is missing for SPWM7
# The air temperature information is missing for TT601
# The air temperature information is missing for KMIO
# The air temperature information is missing for K4F2
# The air temperature information is missing for TT591
# The air temperature information is missing for KXWA
# The air temperature information is missing for KT74
# The air temperature information is missing for KT41
# The air temperature information is missing for TT602
# The air temperature information is missing for TT603
# The air temperature information is missing for KMHP
# The air temperature information is missing for LKRW3
# The air temperature information is missing for BKNW3
# The air temperature information is missing for TT608
# The air temperature information is missing for CNUP1
# The air temperature information is missing for TT610
# The air temperature information is missing for KHMT
# The air temperature information is missing for K00U
# The air temperature information is missing for LXSC1
# The air temperature information is missing for K1EM
# The air temperature information is missing for K1HM
# The air temperature information is missing for K1JM
# The air temperature information is missing for TT613
# The air temperature information is missing for ARWO2
# The air temperature information is missing for SRWO2
# The air temperature information is missing for PHCC1
# The air temperature information is missing for TT618
# The air temperature information is missing for TT619
# The air temperature information is missing for KCPF
# The air temperature information is missing for KE41
# The air temperature information is missing for TT631
# The air temperature information is missing for KMJD
# The air temperature information is missing for JFSC1
# The air temperature information is missing for KVHN
# The air temperature information is missing for K2IS
# The air temperature information is missing for KLNA
# The air temperature information is missing for KT69
# The air temperature information is missing for TT652
# The air temperature information is missing for TT653
# The air temperature information is missing for DICC1
# The air temperature information is missing for KLXC1
# The air temperature information is missing for KADT
# The air temperature information is missing for CQHC1
# The air temperature information is missing for K81R
# The air temperature information is missing for TT662
# The air temperature information is missing for TT663
# The air temperature information is missing for KGNG
# The air temperature information is missing for KT89
# The air temperature information is missing for KE42
# The air temperature information is missing for KRVJ
# The air temperature information is missing for K35A
# The air temperature information is missing for KVVS
# The air temperature information is missing for KMZJ
# The air temperature information is missing for XCDC1
# The air temperature information is missing for TT677
# The air temperature information is missing for TT679
# The air temperature information is missing for OSMC1
# The air temperature information is missing for TT685
# The air temperature information is missing for TT686
# The air temperature information is missing for KO05
# The air temperature information is missing for TT688
# The air temperature information is missing for TT689
# The air temperature information is missing for TT692
# The air temperature information is missing for TT693
# The air temperature information is missing for TT694
# The air temperature information is missing for TT695
# The air temperature information is missing for TT696
# The air temperature information is missing for KT78
# The air temperature information is missing for TT697
# The air temperature information is missing for TFWM6
# The air temperature information is missing for TT700
# The air temperature information is missing for TT701
# The air temperature information is missing for K1R8
# The air temperature information is missing for KHDL
# The air temperature information is missing for TT704
# The air temperature information is missing for TT705
# The air temperature information is missing for TT707
# The air temperature information is missing for TT709
# The air temperature information is missing for TT712
# The air temperature information is missing for KUMP
# The air temperature information is missing for KMQW
# The air temperature information is missing for K8T6
# The air temperature information is missing for KGLX
# The air temperature information is missing for QSFC1
# The air temperature information is missing for QSLC1
# The air temperature information is missing for QSHC1
# The air temperature information is missing for QSOC1
# The air temperature information is missing for QSNC1
# The air temperature information is missing for QSWC1
# The air temperature information is missing for K36K
# The air temperature information is missing for KATA
# The air temperature information is missing for KAGO
# The air temperature information is missing for K15M
# The air temperature information is missing for XMPC1
# The air temperature information is missing for XBKC1
# The air temperature information is missing for XLLC1
# The air temperature information is missing for XMLC1
# The air temperature information is missing for K10G
# The air temperature information is missing for K2G2
# The air temperature information is missing for TT752
# The air temperature information is missing for KGGF
# The air temperature information is missing for KZER
# The air temperature information is missing for KS24
#
# Wrote 4176 stations to /Users/jameshayes/API_data.txt

# %%
#
# Remove lines with missing data
#

lines = []
# read file
with open(full_file, 'r') as f:
    # read an store all lines into list
    lines = f.readlines()

# Write file
with open(full_file, 'w') as f:
    # iterate each line
    for line in lines:
          
        # condition for data to be deleted
        if 'None' not in line:
        #if line.strip("\n") != 'None': 
            f.write(line)

# %%
import os
import sys

#
# Read in the blacklist and remove those lines
#

values = []
lines = []

#Set the path and file name of the blacklist file
#Set the path to your installation directory

#
path_to_file = ('/home/ec2-user/') # ***THIS NEEDS TO BE CHANGED***
name_of_file = ('blacklist.txt') # file containing the blacklisted files.
new_fileName = f'{path_to_file}{name_of_file}'

# read blacklist file

try:

    with open(new_fileName, 'r') as f:
        values = f.readlines()
        for i,n in enumerate(values):
            values[i] = n.strip("\n")          
        
except os.error as err:
       print(f"Unable to open {new_fileName}: {err}", file=sys.stderr)      
                                     
dummy_name = 'test1009.txt'
dummy_file = f'{path_to_file}{dummy_name}' 

#number of values
a = (len(values))
print(values)

#
# Set the values for checking in the loop
#

print(f'There are {a} members of the blacklist')
        
with open(full_file, 'r') as f:
        lines = f.readlines()
        print(f'read in the file {full_file}')
                  
with open(full_file, 'w') as fd:
         print(f'writing the file {full_file}')
         for line in lines:
                
                result = any(map(line.startswith, values))
                if result == False:
                    fd.writelines(line)
# Out:
# ['KGIF', 'KDWX', 'TT087', 'CADL1', 'QPSA3', 'KNQI', 'FRCW1', 'WINM6', 'BOLG1', 'FCRM8', 'CPMG1', 'K1CM', 'KMJD', 'TOGC1']
# There are 14 members of the blacklist
# read in the file /Users/jameshayes/API_data.txt
# writing the file /Users/jameshayes/API_data.txt

# %%
import datetime as datetime
from datetime import datetime  
from datetime import timezone

#
# Set up panda DataFrames parameters
# This is where the data is prepared for HTML presentation
# using pandas
#

#
# Determine the time
#

dt = (datetime.now(timezone.utc))
dt1 = ((dt.strftime("%m")) + "/" + (dt.strftime("%d") + "/" ) + (dt.strftime("%Y")))
dh = (dt.strftime("%H"))

compTime = dh
compTime = int(dh)


if compTime >= 0 and compTime < 1:
    timeUTC = "01z"
elif compTime >= 1 and compTime < 6:
    timeUTC = "06z"    
elif compTime >= 6 and compTime < 12:
    timeUTC = "12z"
elif compTime >= 12 and compTime < 13:
    timeUTC = "13z"
elif compTime >= 13 and compTime < 18:
    timeUTC = "18z"
elif compTime >= 18 and compTime < 24:
    timeUTC = "00z"
else:
    timeUTC = "00z"

print(compTime,timeUTC)
        
df = pd.read_csv(full_file, names = ['STID', 'Location', 'State','Lat', 'Lon', 'Elev','TZ','Date','LOW','Time_Min_UTC','HIGH', 'Time_Max_UTC'] )
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1500)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.precision', 2)

#
# Set the path 
#
# This path is where you want to the created HTML files to reside. It is 
# different from the installation directory. Check with the webmaster 
# to fins the path to the coreect directory on your system
#

new_Path = ('/var/www/html/000/') # ***THIS NEEDS TO BE CHANGED***

#
# Write the MAX html file first
#

ccc = (df.sort_values(by="HIGH", ascending=False))
cccc = ccc.round({"HIGH":0})
cccc.head(50).to_html(new_Path + 'Max' + '.html', index = False)

#
# Now write the MIN html file
#

ddd = (df.sort_values(by='LOW', ascending=True))
dddd = ddd.round({"LOW":0})
dddd.head(50).to_html(new_Path + 'Min' + '.html', index = False)
# Out:
# 2 06z
