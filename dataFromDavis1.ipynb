# %%
import collections
import hashlib
import hmac
import time
from datetime import datetime
import requests
import json
import dataFile
import getData
import checkDST
import getStartEnd

#
# Start the module
#

def dataFromDavis1():
    
    import getStartEnd
    startEnd = getStartEnd.getStartEnd()
    start, end = startEnd[0], startEnd[1]
 
    print(start, end)    
    
    parameters = {
      "api-key": "vy8jbrjsxlbwgojepq3vfyfqfywyhvbd", 
      "api-secret": "sdqfm6wdfy9w0pqp2vdka38o6b4vcsvc",
      "station-id": 81211, 
      "end-timestamp": end,
      "start-timestamp": start,
      "t": int(time.time())
    }

    parameters = collections.OrderedDict(sorted(parameters.items()))

   #for key in parameters:
   #     print("Parameter name: \"{}\" has value \"{}\"".format(key, parameters[key]))

    apiSecret = parameters["api-secret"];
    parameters.pop("api-secret", None);

    data = ""
    for key in parameters:
        data = data + key + str(parameters[key])

    #logger.info('Data string to hash is: \"{}\"'.format(data))   


    apiSignature = hmac.new(
      apiSecret.encode('utf-8'),
      data.encode('utf-8'),
      hashlib.sha256
    ).hexdigest()


    #logger.info('API Signature is: \"{}\"'.format(apiSignature))

    # Building the URL to get the station

    first_part = ('https://api.weatherlink.com/v2/historic/81211?')
    api_key = ('api-key=vy8jbrjsxlbwgojepq3vfyfqfywyhvbd')
    add_apisig = ('&api-signature=')
    add_t = ('&t='+ str(int(time.time())))

    start1 = "&start-timestamp=" + start
    end1 = "&end-timestamp=" + end

    URLfinal = (first_part + api_key + add_t + start1 + end1 + add_apisig + apiSignature)

    r =  requests.get(URLfinal)
    davisAPI = (r.json())
    
    return(davisAPI)

dataFromDavis1()
# Out:
# ('March', '03', '26', '2024')
# This script started at: 2024-03-27 17:55:49.272744
# 2024-03-27 17:30:00 2024-03-27 18:30:00
# {'station_id_uuid': '245f6069-3309-4f78-aa0e-8f97d4e5d6ec',
#  'sensors': [{'lsid': 274372,
#    'data': [{'temp_in_lo_at': 1711517127,
#      'arch_int': 60,
#      'temp_in_hi': 72.4,
#      'temp_in_hi_at': 1711517157,
#      'hum_in_hi': 35,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.3,
#      'hum_in_lo': 34.9,
#      'hum_in_last': 35,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711517127,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711517157,
#      'ts': 1711517160},
#     {'temp_in_lo_at': 1711517217,
#      'arch_int': 60,
#      'temp_in_hi': 72.5,
#      'temp_in_hi_at': 1711517187,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.8,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711517187,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711517187,
#      'ts': 1711517220},
#     {'temp_in_lo_at': 1711517247,
#      'arch_int': 60,
#      'temp_in_hi': 72.5,
#      'temp_in_hi_at': 1711517277,
#      'hum_in_hi': 35,
#      'temp_in_last': 72.5,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 35,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711517247,
#      'tz_offset': -14400,
#      'heat_index_in': 70.3,
#      'hum_in_hi_at': 1711517277,
#      'ts': 1711517280},
#     {'temp_in_lo_at': 1711517307,
#      'arch_int': 60,
#      'temp_in_hi': 72.4,
#      'temp_in_hi_at': 1711517307,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.8,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711517307,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711517307,
#      'ts': 1711517340},
#     {'temp_in_lo_at': 1711517367,
#      'arch_int': 60,
#      'temp_in_hi': 72.3,
#      'temp_in_hi_at': 1711517397,
#      'hum_in_hi': 35.1,
#      'temp_in_last': 72.3,
#      'temp_in_lo': 72.2,
#      'hum_in_lo': 34.8,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711517397,
#      'tz_offset': -14400,
#      'heat_index_in': 69.9,
#      'hum_in_hi_at': 1711517367,
#      'ts': 1711517400},
#     {'temp_in_lo_at': 1711517427,
#      'arch_int': 60,
#      'temp_in_hi': 72.4,
#      'temp_in_hi_at': 1711517457,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.3,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711517457,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711517427,
#      'ts': 1711517460},
#     {'temp_in_lo_at': 1711517517,
#      'arch_int': 60,
#      'temp_in_hi': 72.5,
#      'temp_in_hi_at': 1711517487,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.3,
#      'temp_in_lo': 72.3,
#      'hum_in_lo': 34.8,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711517487,
#      'tz_offset': -14400,
#      'heat_index_in': 69.9,
#      'hum_in_hi_at': 1711517487,
#      'ts': 1711517520},
#     {'temp_in_lo_at': 1711517547,
#      'arch_int': 60,
#      'temp_in_hi': 72.4,
#      'temp_in_hi_at': 1711517547,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711517578,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711517547,
#      'ts': 1711517580},
#     {'temp_in_lo_at': 1711517638,
#      'arch_int': 60,
#      'temp_in_hi': 72.5,
#      'temp_in_hi_at': 1711517608,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711517608,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711517638,
#      'ts': 1711517640},
#     {'temp_in_lo_at': 1711517668,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711517698,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711517668,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711517668,
#      'ts': 1711517700},
#     {'temp_in_lo_at': 1711517728,
#      'arch_int': 60,
#      'temp_in_hi': 72.4,
#      'temp_in_hi_at': 1711517728,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711517728,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711517728,
#      'ts': 1711517760},
#     {'temp_in_lo_at': 1711517818,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711517788,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 42.9,
#      'hum_in_lo_at': 1711517818,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711517788,
#      'ts': 1711517820},
#     {'temp_in_lo_at': 1711517878,
#      'arch_int': 60,
#      'temp_in_hi': 72.4,
#      'temp_in_hi_at': 1711517848,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.3,
#      'temp_in_lo': 72.3,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711517848,
#      'tz_offset': -14400,
#      'heat_index_in': 69.9,
#      'hum_in_hi_at': 1711517878,
#      'ts': 1711517880},
#     {'temp_in_lo_at': 1711517908,
#      'arch_int': 60,
#      'temp_in_hi': 72.4,
#      'temp_in_hi_at': 1711517908,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 42.9,
#      'hum_in_lo_at': 1711517938,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711517908,
#      'ts': 1711517940},
#     {'temp_in_lo_at': 1711517998,
#      'arch_int': 60,
#      'temp_in_hi': 72.4,
#      'temp_in_hi_at': 1711517968,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.3,
#      'temp_in_lo': 72.3,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 42.8,
#      'hum_in_lo_at': 1711517998,
#      'tz_offset': -14400,
#      'heat_index_in': 69.9,
#      'hum_in_hi_at': 1711517968,
#      'ts': 1711518000},
#     {'temp_in_lo_at': 1711518028,
#      'arch_int': 60,
#      'temp_in_hi': 72.4,
#      'temp_in_hi_at': 1711518058,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.3,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711518028,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711518058,
#      'ts': 1711518060},
#     {'temp_in_lo_at': 1711518088,
#      'arch_int': 60,
#      'temp_in_hi': 72.5,
#      'temp_in_hi_at': 1711518118,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.5,
#      'temp_in_lo': 72.3,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711518088,
#      'tz_offset': -14400,
#      'heat_index_in': 70.2,
#      'hum_in_hi_at': 1711518118,
#      'ts': 1711518120},
#     {'temp_in_lo_at': 1711518148,
#      'arch_int': 60,
#      'temp_in_hi': 72.4,
#      'temp_in_hi_at': 1711518148,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 42.9,
#      'hum_in_lo_at': 1711518148,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711518148,
#      'ts': 1711518180},
#     {'temp_in_lo_at': 1711518208,
#      'arch_int': 60,
#      'temp_in_hi': 72.3,
#      'temp_in_hi_at': 1711518208,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.3,
#      'temp_in_lo': 72.3,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 42.8,
#      'hum_in_lo_at': 1711518208,
#      'tz_offset': -14400,
#      'heat_index_in': 69.9,
#      'hum_in_hi_at': 1711518208,
#      'ts': 1711518240},
#     {'temp_in_lo_at': 1711518268,
#      'arch_int': 60,
#      'temp_in_hi': 72.3,
#      'temp_in_hi_at': 1711518268,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.3,
#      'temp_in_lo': 72.3,
#      'hum_in_lo': 34.3,
#      'hum_in_last': 34.3,
#      'dew_point_in': 42.6,
#      'hum_in_lo_at': 1711518298,
#      'tz_offset': -14400,
#      'heat_index_in': 69.9,
#      'hum_in_hi_at': 1711518268,
#      'ts': 1711518300},
#     {'temp_in_lo_at': 1711518328,
#      'arch_int': 60,
#      'temp_in_hi': 72.4,
#      'temp_in_hi_at': 1711518358,
#      'hum_in_hi': 34.3,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.3,
#      'hum_in_lo': 34.3,
#      'hum_in_last': 34.3,
#      'dew_point_in': 42.7,
#      'hum_in_lo_at': 1711518328,
#      'tz_offset': -14400,
#      'heat_index_in': 70,
#      'hum_in_hi_at': 1711518328,
#      'ts': 1711518360},
#     {'temp_in_lo_at': 1711518418,
#      'arch_int': 60,
#      'temp_in_hi': 72.4,
#      'temp_in_hi_at': 1711518388,
#      'hum_in_hi': 34.4,
#      'temp_in_last': 72.3,
#      'temp_in_lo': 72.3,
#      'hum_in_lo': 34.3,
#      'hum_in_last': 34.4,
#      'dew_point_in': 42.7,
#      'hum_in_lo_at': 1711518388,
#      'tz_offset': -14400,
#      'heat_index_in': 69.9,
#      'hum_in_hi_at': 1711518418,
#      'ts': 1711518420},
#     {'temp_in_lo_at': 1711518448,
#      'arch_int': 60,
#      'temp_in_hi': 72.4,
#      'temp_in_hi_at': 1711518478,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.2,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711518448,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711518448,
#      'ts': 1711518480},
#     {'temp_in_lo_at': 1711518538,
#      'arch_int': 60,
#      'temp_in_hi': 72.5,
#      'temp_in_hi_at': 1711518508,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711518508,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711518508,
#      'ts': 1711518540},
#     {'temp_in_lo_at': 1711518568,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711518598,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711518598,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711518568,
#      'ts': 1711518600},
#     {'temp_in_lo_at': 1711518658,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711518628,
#      'hum_in_hi': 35,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.9,
#      'hum_in_last': 35,
#      'dew_point_in': 43.4,
#      'hum_in_lo_at': 1711518628,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711518658,
#      'ts': 1711518660},
#     {'temp_in_lo_at': 1711518718,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711518688,
#      'hum_in_hi': 35,
#      'temp_in_last': 72.4,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.8,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711518718,
#      'tz_offset': -14400,
#      'heat_index_in': 70.1,
#      'hum_in_hi_at': 1711518688,
#      'ts': 1711518720},
#     {'temp_in_lo_at': 1711518748,
#      'arch_int': 60,
#      'temp_in_hi': 72.5,
#      'temp_in_hi_at': 1711518748,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.5,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711518748,
#      'tz_offset': -14400,
#      'heat_index_in': 70.2,
#      'hum_in_hi_at': 1711518778,
#      'ts': 1711518780},
#     {'temp_in_lo_at': 1711518838,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711518808,
#      'hum_in_hi': 34.9,
#      'temp_in_last': 72.5,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.8,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711518838,
#      'tz_offset': -14400,
#      'heat_index_in': 70.2,
#      'hum_in_hi_at': 1711518808,
#      'ts': 1711518840},
#     {'temp_in_lo_at': 1711518868,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711518898,
#      'hum_in_hi': 35,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.8,
#      'hum_in_last': 35,
#      'dew_point_in': 43.4,
#      'hum_in_lo_at': 1711518868,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711518898,
#      'ts': 1711518900},
#     {'temp_in_lo_at': 1711518958,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711518928,
#      'hum_in_hi': 34.9,
#      'temp_in_last': 72.5,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.8,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711518958,
#      'tz_offset': -14400,
#      'heat_index_in': 70.2,
#      'hum_in_hi_at': 1711518928,
#      'ts': 1711518960},
#     {'temp_in_lo_at': 1711519018,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711518988,
#      'hum_in_hi': 34.9,
#      'temp_in_last': 72.5,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711519018,
#      'tz_offset': -14400,
#      'heat_index_in': 70.2,
#      'hum_in_hi_at': 1711518988,
#      'ts': 1711519020},
#     {'temp_in_lo_at': 1711519048,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711519078,
#      'hum_in_hi': 34.9,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.9,
#      'hum_in_last': 34.9,
#      'dew_point_in': 43.5,
#      'hum_in_lo_at': 1711519048,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711519048,
#      'ts': 1711519080},
#     {'temp_in_lo_at': 1711519108,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711519138,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711519138,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711519108,
#      'ts': 1711519140},
#     {'temp_in_lo_at': 1711519168,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711519198,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711519168,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711519168,
#      'ts': 1711519200},
#     {'temp_in_lo_at': 1711519258,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711519228,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.5,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711519258,
#      'tz_offset': -14400,
#      'heat_index_in': 70.2,
#      'hum_in_hi_at': 1711519228,
#      'ts': 1711519260},
#     {'temp_in_lo_at': 1711519288,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711519288,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711519288,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711519288,
#      'ts': 1711519320},
#     {'temp_in_lo_at': 1711519378,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711519348,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711519348,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711519348,
#      'ts': 1711519380},
#     {'temp_in_lo_at': 1711519438,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711519408,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711519408,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711519408,
#      'ts': 1711519440},
#     {'temp_in_lo_at': 1711519499,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711519468,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711519499,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711519468,
#      'ts': 1711519500},
#     {'temp_in_lo_at': 1711519529,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711519529,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711519559,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711519529,
#      'ts': 1711519560},
#     {'temp_in_lo_at': 1711519619,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711519589,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711519589,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711519619,
#      'ts': 1711519620},
#     {'temp_in_lo_at': 1711519649,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711519649,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711519679,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711519649,
#      'ts': 1711519680},
#     {'temp_in_lo_at': 1711519709,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711519709,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711519709,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711519709,
#      'ts': 1711519740},
#     {'temp_in_lo_at': 1711519769,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711519799,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711519769,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711519769,
#      'ts': 1711519800},
#     {'temp_in_lo_at': 1711519829,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711519859,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711519829,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711519859,
#      'ts': 1711519860},
#     {'temp_in_lo_at': 1711519889,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711519889,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711519889,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711519889,
#      'ts': 1711519920},
#     {'temp_in_lo_at': 1711519949,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711519979,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711519949,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711519979,
#      'ts': 1711519980},
#     {'temp_in_lo_at': 1711520009,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711520039,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711520039,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711520009,
#      'ts': 1711520040},
#     {'temp_in_lo_at': 1711520099,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711520069,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.5,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.4,
#      'dew_point_in': 42.9,
#      'hum_in_lo_at': 1711520099,
#      'tz_offset': -14400,
#      'heat_index_in': 70.2,
#      'hum_in_hi_at': 1711520069,
#      'ts': 1711520100},
#     {'temp_in_lo_at': 1711520129,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711520159,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.3,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711520129,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711520159,
#      'ts': 1711520160},
#     {'temp_in_lo_at': 1711520219,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711520189,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.5,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.3,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711520189,
#      'tz_offset': -14400,
#      'heat_index_in': 70.2,
#      'hum_in_hi_at': 1711520219,
#      'ts': 1711520220},
#     {'temp_in_lo_at': 1711520249,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711520279,
#      'hum_in_hi': 34.3,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.2,
#      'hum_in_last': 34.3,
#      'dew_point_in': 42.9,
#      'hum_in_lo_at': 1711520249,
#      'tz_offset': -14400,
#      'heat_index_in': 70.3,
#      'hum_in_hi_at': 1711520279,
#      'ts': 1711520280},
#     {'temp_in_lo_at': 1711520309,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711520339,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711520309,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711520339,
#      'ts': 1711520340},
#     {'temp_in_lo_at': 1711520369,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711520399,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.5,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711520369,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711520369,
#      'ts': 1711520400},
#     {'temp_in_lo_at': 1711520429,
#      'arch_int': 60,
#      'temp_in_hi': 72.5,
#      'temp_in_hi_at': 1711520459,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.5,
#      'temp_in_lo': 72.4,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711520459,
#      'tz_offset': -14400,
#      'heat_index_in': 70.2,
#      'hum_in_hi_at': 1711520429,
#      'ts': 1711520460},
#     {'temp_in_lo_at': 1711520489,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711520489,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711520489,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711520489,
#      'ts': 1711520520},
#     {'temp_in_lo_at': 1711520549,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711520549,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711520549,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711520549,
#      'ts': 1711520580},
#     {'temp_in_lo_at': 1711520609,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711520609,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711520639,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711520609,
#      'ts': 1711520640},
#     {'temp_in_lo_at': 1711520669,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711520669,
#      'hum_in_hi': 34.9,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.9,
#      'hum_in_last': 34.9,
#      'dew_point_in': 43.5,
#      'hum_in_lo_at': 1711520669,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711520669,
#      'ts': 1711520700},
#     {'temp_in_lo_at': 1711520729,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711520729,
#      'hum_in_hi': 34.9,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711520759,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711520729,
#      'ts': 1711520760},
#     {'temp_in_lo_at': 1711520789,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711520819,
#      'hum_in_hi': 34.9,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711520819,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711520789,
#      'ts': 1711520820},
#     {'temp_in_lo_at': 1711520849,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711520879,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.7,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711520849,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711520879,
#      'ts': 1711520880},
#     {'temp_in_lo_at': 1711520909,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711520939,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.8,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43.5,
#      'hum_in_lo_at': 1711520909,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711520909,
#      'ts': 1711520940},
#     {'temp_in_lo_at': 1711520999,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711520969,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711520969,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711520969,
#      'ts': 1711521000},
#     {'temp_in_lo_at': 1711521029,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711521059,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.7,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43.4,
#      'hum_in_lo_at': 1711521029,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711521059,
#      'ts': 1711521060},
#     {'temp_in_lo_at': 1711521119,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711521089,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711521089,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711521089,
#      'ts': 1711521120},
#     {'temp_in_lo_at': 1711521149,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711521179,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.4,
#      'hum_in_lo_at': 1711521149,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711521179,
#      'ts': 1711521180},
#     {'temp_in_lo_at': 1711521209,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711521209,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43.4,
#      'hum_in_lo_at': 1711521209,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711521239,
#      'ts': 1711521240},
#     {'temp_in_lo_at': 1711521269,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711521269,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711521299,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711521269,
#      'ts': 1711521300},
#     {'temp_in_lo_at': 1711521329,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711521329,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711521359,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711521329,
#      'ts': 1711521360},
#     {'temp_in_lo_at': 1711521420,
#      'arch_int': 60,
#      'temp_in_hi': 73,
#      'temp_in_hi_at': 1711521389,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711521389,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711521420,
#      'ts': 1711521420},
#     {'temp_in_lo_at': 1711521450,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711521450,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711521450,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711521480,
#      'ts': 1711521480},
#     {'temp_in_lo_at': 1711521540,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711521510,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711521510,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711521540,
#      'ts': 1711521540},
#     {'temp_in_lo_at': 1711521600,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711521570,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.4,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711521600,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711521570,
#      'ts': 1711521600},
#     {'temp_in_lo_at': 1711521630,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711521630,
#      'hum_in_hi': 34.4,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.4,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711521630,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711521630,
#      'ts': 1711521660},
#     {'temp_in_lo_at': 1711521660,
#      'arch_int': 60,
#      'temp_in_hi': 72.6,
#      'temp_in_hi_at': 1711521660,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.3,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711521660,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711521690,
#      'ts': 1711521720},
#     {'temp_in_lo_at': 1711521720,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711521750,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.2,
#      'hum_in_last': 34.2,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711521750,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711521720,
#      'ts': 1711521780},
#     {'temp_in_lo_at': 1711521780,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711521780,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711521780,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711521780,
#      'ts': 1711521840},
#     {'temp_in_lo_at': 1711521840,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711521870,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.3,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711521870,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711521840,
#      'ts': 1711521900},
#     {'temp_in_lo_at': 1711521930,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711521930,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711521930,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711521930,
#      'ts': 1711521960},
#     {'temp_in_lo_at': 1711521990,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711521960,
#      'hum_in_hi': 34.4,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.3,
#      'hum_in_last': 34.3,
#      'dew_point_in': 42.9,
#      'hum_in_lo_at': 1711521990,
#      'tz_offset': -14400,
#      'heat_index_in': 70.3,
#      'hum_in_hi_at': 1711521960,
#      'ts': 1711522020},
#     {'temp_in_lo_at': 1711522020,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711522050,
#      'hum_in_hi': 34.4,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.3,
#      'hum_in_last': 34.4,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711522020,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711522050,
#      'ts': 1711522080},
#     {'temp_in_lo_at': 1711522080,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711522110,
#      'hum_in_hi': 34.3,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.3,
#      'hum_in_last': 34.3,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711522080,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711522080,
#      'ts': 1711522140},
#     {'temp_in_lo_at': 1711522140,
#      'arch_int': 60,
#      'temp_in_hi': 72.7,
#      'temp_in_hi_at': 1711522140,
#      'hum_in_hi': 34.3,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.2,
#      'hum_in_last': 34.2,
#      'dew_point_in': 42.9,
#      'hum_in_lo_at': 1711522170,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711522140,
#      'ts': 1711522200},
#     {'temp_in_lo_at': 1711522200,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711522230,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.4,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711522230,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711522200,
#      'ts': 1711522260},
#     {'temp_in_lo_at': 1711522260,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711522290,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711522260,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711522290,
#      'ts': 1711522320},
#     {'temp_in_lo_at': 1711522320,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711522320,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43.4,
#      'hum_in_lo_at': 1711522320,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711522350,
#      'ts': 1711522380},
#     {'temp_in_lo_at': 1711522410,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711522380,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.8,
#      'hum_in_last': 34.8,
#      'dew_point_in': 43.4,
#      'hum_in_lo_at': 1711522380,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711522380,
#      'ts': 1711522440},
#     {'temp_in_lo_at': 1711522440,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711522470,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711522470,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711522440,
#      'ts': 1711522500},
#     {'temp_in_lo_at': 1711522530,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711522500,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711522530,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711522500,
#      'ts': 1711522560},
#     {'temp_in_lo_at': 1711522560,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711522590,
#      'hum_in_hi': 34.8,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.4,
#      'hum_in_lo_at': 1711522590,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711522560,
#      'ts': 1711522620},
#     {'temp_in_lo_at': 1711522620,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711522650,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711522620,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711522620,
#      'ts': 1711522680},
#     {'temp_in_lo_at': 1711522680,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711522680,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.9,
#      'hum_in_lo': 34.6,
#      'hum_in_last': 34.6,
#      'dew_point_in': 43.4,
#      'hum_in_lo_at': 1711522680,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711522680,
#      'ts': 1711522740},
#     {'temp_in_lo_at': 1711522740,
#      'arch_int': 60,
#      'temp_in_hi': 73,
#      'temp_in_hi_at': 1711522770,
#      'hum_in_hi': 34.6,
#      'temp_in_last': 73,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.4,
#      'hum_in_lo_at': 1711522770,
#      'tz_offset': -14400,
#      'heat_index_in': 71,
#      'hum_in_hi_at': 1711522740,
#      'ts': 1711522800},
#     {'temp_in_lo_at': 1711522830,
#      'arch_int': 60,
#      'temp_in_hi': 73.1,
#      'temp_in_hi_at': 1711522800,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.9,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711522800,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711522800,
#      'ts': 1711522860},
#     {'temp_in_lo_at': 1711522890,
#      'arch_int': 60,
#      'temp_in_hi': 73,
#      'temp_in_hi_at': 1711522860,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.9,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711522860,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711522860,
#      'ts': 1711522920},
#     {'temp_in_lo_at': 1711522920,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711522950,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711522920,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711522950,
#      'ts': 1711522980},
#     {'temp_in_lo_at': 1711523010,
#      'arch_int': 60,
#      'temp_in_hi': 73,
#      'temp_in_hi_at': 1711522980,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.9,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.4,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711523010,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711522980,
#      'ts': 1711523040},
#     {'temp_in_lo_at': 1711523070,
#      'arch_int': 60,
#      'temp_in_hi': 73,
#      'temp_in_hi_at': 1711523040,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.9,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.4,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711523070,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711523040,
#      'ts': 1711523100},
#     {'temp_in_lo_at': 1711523100,
#      'arch_int': 60,
#      'temp_in_hi': 73.1,
#      'temp_in_hi_at': 1711523130,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 73.1,
#      'temp_in_lo': 73,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.4,
#      'dew_point_in': 43.4,
#      'hum_in_lo_at': 1711523130,
#      'tz_offset': -14400,
#      'heat_index_in': 71.1,
#      'hum_in_hi_at': 1711523100,
#      'ts': 1711523160},
#     {'temp_in_lo_at': 1711523160,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711523190,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711523160,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711523190,
#      'ts': 1711523220},
#     {'temp_in_lo_at': 1711523250,
#      'arch_int': 60,
#      'temp_in_hi': 73,
#      'temp_in_hi_at': 1711523220,
#      'hum_in_hi': 34.3,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.9,
#      'hum_in_lo': 34.2,
#      'hum_in_last': 34.2,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711523250,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711523220,
#      'ts': 1711523280},
#     {'temp_in_lo_at': 1711523280,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711523310,
#      'hum_in_hi': 34.4,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.4,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711523280,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711523280,
#      'ts': 1711523340},
#     {'temp_in_lo_at': 1711523371,
#      'arch_int': 60,
#      'temp_in_hi': 73,
#      'temp_in_hi_at': 1711523341,
#      'hum_in_hi': 34.7,
#      'temp_in_last': 72.6,
#      'temp_in_lo': 72.6,
#      'hum_in_lo': 34.5,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711523371,
#      'tz_offset': -14400,
#      'heat_index_in': 70.4,
#      'hum_in_hi_at': 1711523341,
#      'ts': 1711523400},
#     {'temp_in_lo_at': 1711523431,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711523401,
#      'hum_in_hi': 34.5,
#      'temp_in_last': 72.7,
#      'temp_in_lo': 72.7,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.5,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711523401,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711523431,
#      'ts': 1711523460},
#     {'temp_in_lo_at': 1711523461,
#      'arch_int': 60,
#      'temp_in_hi': 73,
#      'temp_in_hi_at': 1711523491,
#      'hum_in_hi': 34.4,
#      'temp_in_last': 73,
#      'temp_in_lo': 72.9,
#      'hum_in_lo': 34.2,
#      'hum_in_last': 34.4,
#      'dew_point_in': 43.3,
#      'hum_in_lo_at': 1711523461,
#      'tz_offset': -14400,
#      'heat_index_in': 70.9,
#      'hum_in_hi_at': 1711523491,
#      'ts': 1711523520},
#     {'temp_in_lo_at': 1711523521,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711523551,
#      'hum_in_hi': 34.4,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.4,
#      'hum_in_last': 34.4,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711523521,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711523521,
#      'ts': 1711523580},
#     {'temp_in_lo_at': 1711523611,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711523581,
#      'hum_in_hi': 34.4,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.2,
#      'hum_in_last': 34.2,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711523611,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711523581,
#      'ts': 1711523640},
#     {'temp_in_lo_at': 1711523641,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711523641,
#      'hum_in_hi': 34.2,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.1,
#      'hum_in_last': 34.1,
#      'dew_point_in': 42.9,
#      'hum_in_lo_at': 1711523671,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711523641,
#      'ts': 1711523700},
#     {'temp_in_lo_at': 1711523701,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711523701,
#      'hum_in_hi': 34.2,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.9,
#      'hum_in_lo': 34.2,
#      'hum_in_last': 34.2,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711523701,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711523701,
#      'ts': 1711523760},
#     {'temp_in_lo_at': 1711523791,
#      'arch_int': 60,
#      'temp_in_hi': 73,
#      'temp_in_hi_at': 1711523761,
#      'hum_in_hi': 34.3,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.2,
#      'hum_in_last': 34.2,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711523791,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711523761,
#      'ts': 1711523820},
#     {'temp_in_lo_at': 1711523821,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711523821,
#      'hum_in_hi': 34.4,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.9,
#      'hum_in_lo': 34.2,
#      'hum_in_last': 34.4,
#      'dew_point_in': 43.2,
#      'hum_in_lo_at': 1711523821,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711523851,
#      'ts': 1711523880},
#     {'temp_in_lo_at': 1711523911,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711523881,
#      'hum_in_hi': 34.2,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.2,
#      'hum_in_last': 34.2,
#      'dew_point_in': 43,
#      'hum_in_lo_at': 1711523881,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711523881,
#      'ts': 1711523940},
#     {'temp_in_lo_at': 1711523941,
#      'arch_int': 60,
#      'temp_in_hi': 72.8,
#      'temp_in_hi_at': 1711523941,
#      'hum_in_hi': 34.4,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34.2,
#      'hum_in_last': 34.4,
#      'dew_point_in': 43.1,
#      'hum_in_lo_at': 1711523941,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711523971,
#      'ts': 1711524000},
#     {'temp_in_lo_at': 1711524031,
#      'arch_int': 60,
#      'temp_in_hi': 73,
#      'temp_in_hi_at': 1711524001,
#      'hum_in_hi': 34.1,
#      'temp_in_last': 72.8,
#      'temp_in_lo': 72.8,
#      'hum_in_lo': 34,
#      'hum_in_last': 34,
#      'dew_point_in': 42.8,
#      'hum_in_lo_at': 1711524031,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711524001,
#      'ts': 1711524060},
#     {'temp_in_lo_at': 1711524061,
#      'arch_int': 60,
#      'temp_in_hi': 72.9,
#      'temp_in_hi_at': 1711524061,
#      'hum_in_hi': 34.1,
#      'temp_in_last': 72.9,
#      'temp_in_lo': 72.9,
# ...
#      'bar_lo': 30.117,
#      'bar_hi': 30.118,
#      'bar_lo_at': 1711572475,
#      'ts': 1711572480},
#     {'bar_absolute': 30.082,
#      'bar_hi_at': 1711572505,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.11,
#      'arch_int': 60,
#      'bar_lo': 30.11,
#      'bar_hi': 30.113,
#      'bar_lo_at': 1711572536,
#      'ts': 1711572540},
#     {'bar_absolute': 30.083,
#      'bar_hi_at': 1711572566,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.111,
#      'arch_int': 60,
#      'bar_lo': 30.111,
#      'bar_hi': 30.111,
#      'bar_lo_at': 1711572566,
#      'ts': 1711572600},
#     {'bar_absolute': 30.083,
#      'bar_hi_at': 1711572627,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.111,
#      'arch_int': 60,
#      'bar_lo': 30.111,
#      'bar_hi': 30.115,
#      'bar_lo_at': 1711572658,
#      'ts': 1711572660},
#     {'bar_absolute': 30.088,
#      'bar_hi_at': 1711572718,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.116,
#      'arch_int': 60,
#      'bar_lo': 30.11,
#      'bar_hi': 30.116,
#      'bar_lo_at': 1711572688,
#      'ts': 1711572720},
#     {'bar_absolute': 30.088,
#      'bar_hi_at': 1711572749,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.116,
#      'arch_int': 60,
#      'bar_lo': 30.116,
#      'bar_hi': 30.117,
#      'bar_lo_at': 1711572779,
#      'ts': 1711572780},
#     {'bar_absolute': 30.089,
#      'bar_hi_at': 1711572810,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.117,
#      'arch_int': 60,
#      'bar_lo': 30.117,
#      'bar_hi': 30.117,
#      'bar_lo_at': 1711572810,
#      'ts': 1711572840},
#     {'bar_absolute': 30.089,
#      'bar_hi_at': 1711572871,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.117,
#      'arch_int': 60,
#      'bar_lo': 30.115,
#      'bar_hi': 30.117,
#      'bar_lo_at': 1711572840,
#      'ts': 1711572900},
#     {'bar_absolute': 30.087,
#      'bar_hi_at': 1711572901,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.115,
#      'arch_int': 60,
#      'bar_lo': 30.115,
#      'bar_hi': 30.116,
#      'bar_lo_at': 1711572932,
#      'ts': 1711572960},
#     {'bar_absolute': 30.087,
#      'bar_hi_at': 1711572993,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.115,
#      'arch_int': 60,
#      'bar_lo': 30.111,
#      'bar_hi': 30.115,
#      'bar_lo_at': 1711572962,
#      'ts': 1711573020},
#     {'bar_absolute': 30.087,
#      'bar_hi_at': 1711573054,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.115,
#      'arch_int': 60,
#      'bar_lo': 30.114,
#      'bar_hi': 30.115,
#      'bar_lo_at': 1711573023,
#      'ts': 1711573080},
#     {'bar_absolute': 30.089,
#      'bar_hi_at': 1711573115,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.117,
#      'arch_int': 60,
#      'bar_lo': 30.115,
#      'bar_hi': 30.117,
#      'bar_lo_at': 1711573084,
#      'ts': 1711573140},
#     {'bar_absolute': 30.089,
#      'bar_hi_at': 1711573175,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.117,
#      'arch_int': 60,
#      'bar_lo': 30.116,
#      'bar_hi': 30.117,
#      'bar_lo_at': 1711573145,
#      'ts': 1711573200},
#     {'bar_absolute': 30.089,
#      'bar_hi_at': 1711573236,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.117,
#      'arch_int': 60,
#      'bar_lo': 30.114,
#      'bar_hi': 30.117,
#      'bar_lo_at': 1711573206,
#      'ts': 1711573260},
#     {'bar_absolute': 30.088,
#      'bar_hi_at': 1711573267,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.116,
#      'arch_int': 60,
#      'bar_lo': 30.116,
#      'bar_hi': 30.117,
#      'bar_lo_at': 1711573297,
#      'ts': 1711573320},
#     {'bar_absolute': 30.091,
#      'bar_hi_at': 1711573328,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.119,
#      'arch_int': 60,
#      'bar_lo': 30.119,
#      'bar_hi': 30.119,
#      'bar_lo_at': 1711573328,
#      'ts': 1711573380},
#     {'bar_absolute': 30.091,
#      'bar_hi_at': 1711573419,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.119,
#      'arch_int': 60,
#      'bar_lo': 30.118,
#      'bar_hi': 30.119,
#      'bar_lo_at': 1711573389,
#      'ts': 1711573440},
#     {'bar_absolute': 30.089,
#      'bar_hi_at': 1711573480,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.117,
#      'arch_int': 60,
#      'bar_lo': 30.115,
#      'bar_hi': 30.117,
#      'bar_lo_at': 1711573450,
#      'ts': 1711573500},
#     {'bar_absolute': 30.089,
#      'bar_hi_at': 1711573541,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.117,
#      'arch_int': 60,
#      'bar_lo': 30.115,
#      'bar_hi': 30.117,
#      'bar_lo_at': 1711573511,
#      'ts': 1711573560},
#     {'bar_absolute': 30.09,
#      'bar_hi_at': 1711573572,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.118,
#      'arch_int': 60,
#      'bar_lo': 30.118,
#      'bar_hi': 30.118,
#      'bar_lo_at': 1711573572,
#      'ts': 1711573620},
#     {'bar_absolute': 30.092,
#      'bar_hi_at': 1711573663,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.12,
#      'arch_int': 60,
#      'bar_lo': 30.116,
#      'bar_hi': 30.12,
#      'bar_lo_at': 1711573633,
#      'ts': 1711573680},
#     {'bar_absolute': 30.092,
#      'bar_hi_at': 1711573724,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.12,
#      'arch_int': 60,
#      'bar_lo': 30.119,
#      'bar_hi': 30.12,
#      'bar_lo_at': 1711573693,
#      'ts': 1711573740},
#     {'bar_absolute': 30.088,
#      'bar_hi_at': 1711573754,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.116,
#      'arch_int': 60,
#      'bar_lo': 30.116,
#      'bar_hi': 30.118,
#      'bar_lo_at': 1711573785,
#      'ts': 1711573800},
#     {'bar_absolute': 30.09,
#      'bar_hi_at': 1711573846,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.118,
#      'arch_int': 60,
#      'bar_lo': 30.117,
#      'bar_hi': 30.118,
#      'bar_lo_at': 1711573815,
#      'ts': 1711573860},
#     {'bar_absolute': 30.083,
#      'bar_hi_at': 1711573876,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.111,
#      'arch_int': 60,
#      'bar_lo': 30.111,
#      'bar_hi': 30.111,
#      'bar_lo_at': 1711573876,
#      'ts': 1711573920},
#     {'bar_absolute': 30.079,
#      'bar_hi_at': 1711573937,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.107,
#      'arch_int': 60,
#      'bar_lo': 30.107,
#      'bar_hi': 30.109,
#      'bar_lo_at': 1711573968,
#      'ts': 1711573980},
#     {'bar_absolute': 30.072,
#      'bar_hi_at': 1711573998,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.1,
#      'arch_int': 60,
#      'bar_lo': 30.1,
#      'bar_hi': 30.102,
#      'bar_lo_at': 1711574029,
#      'ts': 1711574040},
#     {'bar_absolute': 30.064,
#      'bar_hi_at': 1711574059,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.092,
#      'arch_int': 60,
#      'bar_lo': 30.092,
#      'bar_hi': 30.094,
#      'bar_lo_at': 1711574090,
#      'ts': 1711574100},
#     {'bar_absolute': 30.058,
#      'bar_hi_at': 1711574120,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.086,
#      'arch_int': 60,
#      'bar_lo': 30.086,
#      'bar_hi': 30.09,
#      'bar_lo_at': 1711574150,
#      'ts': 1711574160},
#     {'bar_absolute': 30.059,
#      'bar_hi_at': 1711574181,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.087,
#      'arch_int': 60,
#      'bar_lo': 30.087,
#      'bar_hi': 30.088,
#      'bar_lo_at': 1711574211,
#      'ts': 1711574220},
#     {'bar_absolute': 30.06,
#      'bar_hi_at': 1711574272,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.088,
#      'arch_int': 60,
#      'bar_lo': 30.086,
#      'bar_hi': 30.088,
#      'bar_lo_at': 1711574242,
#      'ts': 1711574280},
#     {'bar_absolute': 30.059,
#      'bar_hi_at': 1711574303,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.087,
#      'arch_int': 60,
#      'bar_lo': 30.087,
#      'bar_hi': 30.089,
#      'bar_lo_at': 1711574333,
#      'ts': 1711574340},
#     {'bar_absolute': 30.063,
#      'bar_hi_at': 1711574394,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.091,
#      'arch_int': 60,
#      'bar_lo': 30.088,
#      'bar_hi': 30.091,
#      'bar_lo_at': 1711574364,
#      'ts': 1711574400},
#     {'bar_absolute': 30.064,
#      'bar_hi_at': 1711574455,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.092,
#      'arch_int': 60,
#      'bar_lo': 30.091,
#      'bar_hi': 30.092,
#      'bar_lo_at': 1711574425,
#      'ts': 1711574460},
#     {'bar_absolute': 30.063,
#      'bar_hi_at': 1711574486,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.091,
#      'arch_int': 60,
#      'bar_lo': 30.091,
#      'bar_hi': 30.093,
#      'bar_lo_at': 1711574516,
#      'ts': 1711574520},
#     {'bar_absolute': 30.064,
#      'bar_hi_at': 1711574547,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.092,
#      'arch_int': 60,
#      'bar_lo': 30.092,
#      'bar_hi': 30.092,
#      'bar_lo_at': 1711574547,
#      'ts': 1711574580},
#     {'bar_absolute': 30.062,
#      'bar_hi_at': 1711574638,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.09,
#      'arch_int': 60,
#      'bar_lo': 30.089,
#      'bar_hi': 30.09,
#      'bar_lo_at': 1711574608,
#      'ts': 1711574640},
#     {'bar_absolute': 30.06,
#      'bar_hi_at': 1711574668,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.088,
#      'arch_int': 60,
#      'bar_lo': 30.088,
#      'bar_hi': 30.091,
#      'bar_lo_at': 1711574699,
#      'ts': 1711574700},
#     {'bar_absolute': 30.056,
#      'bar_hi_at': 1711574729,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.084,
#      'arch_int': 60,
#      'bar_lo': 30.084,
#      'bar_hi': 30.087,
#      'bar_lo_at': 1711574760,
#      'ts': 1711574760},
#     {'bar_absolute': 30.058,
#      'bar_hi_at': 1711574790,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.086,
#      'arch_int': 60,
#      'bar_lo': 30.086,
#      'bar_hi': 30.086,
#      'bar_lo_at': 1711574790,
#      'ts': 1711574820},
#     {'bar_absolute': 30.053,
#      'bar_hi_at': 1711574821,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.081,
#      'arch_int': 60,
#      'bar_lo': 30.081,
#      'bar_hi': 30.082,
#      'bar_lo_at': 1711574851,
#      'ts': 1711574880},
#     {'bar_absolute': 30.053,
#      'bar_hi_at': 1711574882,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.081,
#      'arch_int': 60,
#      'bar_lo': 30.081,
#      'bar_hi': 30.082,
#      'bar_lo_at': 1711574912,
#      'ts': 1711574940},
#     {'bar_absolute': 30.051,
#      'bar_hi_at': 1711574943,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.079,
#      'arch_int': 60,
#      'bar_lo': 30.079,
#      'bar_hi': 30.082,
#      'bar_lo_at': 1711574973,
#      'ts': 1711575000},
#     {'bar_absolute': 30.054,
#      'bar_hi_at': 1711575004,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.082,
#      'arch_int': 60,
#      'bar_lo': 30.082,
#      'bar_hi': 30.084,
#      'bar_lo_at': 1711575034,
#      'ts': 1711575060},
#     {'bar_absolute': 30.055,
#      'bar_hi_at': 1711575065,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.083,
#      'arch_int': 60,
#      'bar_lo': 30.083,
#      'bar_hi': 30.084,
#      'bar_lo_at': 1711575095,
#      'ts': 1711575120},
#     {'bar_absolute': 30.052,
#      'bar_hi_at': 1711575125,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.08,
#      'arch_int': 60,
#      'bar_lo': 30.08,
#      'bar_hi': 30.081,
#      'bar_lo_at': 1711575156,
#      'ts': 1711575180},
#     {'bar_absolute': 30.054,
#      'bar_hi_at': 1711575217,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.082,
#      'arch_int': 60,
#      'bar_lo': 30.079,
#      'bar_hi': 30.082,
#      'bar_lo_at': 1711575186,
#      'ts': 1711575240},
#     {'bar_absolute': 30.052,
#      'bar_hi_at': 1711575247,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.08,
#      'arch_int': 60,
#      'bar_lo': 30.08,
#      'bar_hi': 30.081,
#      'bar_lo_at': 1711575278,
#      'ts': 1711575300},
#     {'bar_absolute': 30.052,
#      'bar_hi_at': 1711575308,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.08,
#      'arch_int': 60,
#      'bar_lo': 30.08,
#      'bar_hi': 30.08,
#      'bar_lo_at': 1711575308,
#      'ts': 1711575360},
#     {'bar_absolute': 30.048,
#      'bar_hi_at': 1711575369,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.076,
#      'arch_int': 60,
#      'bar_lo': 30.076,
#      'bar_hi': 30.077,
#      'bar_lo_at': 1711575400,
#      'ts': 1711575420},
#     {'bar_absolute': 30.053,
#      'bar_hi_at': 1711575461,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.081,
#      'arch_int': 60,
#      'bar_lo': 30.079,
#      'bar_hi': 30.081,
#      'bar_lo_at': 1711575430,
#      'ts': 1711575480},
#     {'bar_absolute': 30.046,
#      'bar_hi_at': 1711575491,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.074,
#      'arch_int': 60,
#      'bar_lo': 30.074,
#      'bar_hi': 30.074,
#      'bar_lo_at': 1711575491,
#      'ts': 1711575540},
#     {'bar_absolute': 30.042,
#      'bar_hi_at': 1711575552,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.07,
#      'arch_int': 60,
#      'bar_lo': 30.07,
#      'bar_hi': 30.073,
#      'bar_lo_at': 1711575583,
#      'ts': 1711575600},
#     {'bar_absolute': 30.047,
#      'bar_hi_at': 1711575643,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.075,
#      'arch_int': 60,
#      'bar_lo': 30.074,
#      'bar_hi': 30.075,
#      'bar_lo_at': 1711575613,
#      'ts': 1711575660},
#     {'bar_absolute': 30.046,
#      'bar_hi_at': 1711575704,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.074,
#      'arch_int': 60,
#      'bar_lo': 30.073,
#      'bar_hi': 30.074,
#      'bar_lo_at': 1711575674,
#      'ts': 1711575720},
#     {'bar_absolute': 30.042,
#      'bar_hi_at': 1711575734,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.07,
#      'arch_int': 60,
#      'bar_lo': 30.07,
#      'bar_hi': 30.072,
#      'bar_lo_at': 1711575763,
#      'ts': 1711575780},
#     {'bar_absolute': 30.05,
#      'bar_hi_at': 1711575824,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.078,
#      'arch_int': 60,
#      'bar_lo': 30.076,
#      'bar_hi': 30.078,
#      'bar_lo_at': 1711575794,
#      'ts': 1711575840},
#     {'bar_absolute': 30.044,
#      'bar_hi_at': 1711575855,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.072,
#      'arch_int': 60,
#      'bar_lo': 30.072,
#      'bar_hi': 30.075,
#      'bar_lo_at': 1711575885,
#      'ts': 1711575900},
#     {'bar_absolute': 30.045,
#      'bar_hi_at': 1711575916,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.073,
#      'arch_int': 60,
#      'bar_lo': 30.073,
#      'bar_hi': 30.075,
#      'bar_lo_at': 1711575946,
#      'ts': 1711575960},
#     {'bar_absolute': 30.044,
#      'bar_hi_at': 1711575977,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.072,
#      'arch_int': 60,
#      'bar_lo': 30.072,
#      'bar_hi': 30.073,
#      'bar_lo_at': 1711576007,
#      'ts': 1711576020},
#     {'bar_absolute': 30.045,
#      'bar_hi_at': 1711576038,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.073,
#      'arch_int': 60,
#      'bar_lo': 30.073,
#      'bar_hi': 30.075,
#      'bar_lo_at': 1711576068,
#      'ts': 1711576080},
#     {'bar_absolute': 30.044,
#      'bar_hi_at': 1711576129,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.072,
#      'arch_int': 60,
#      'bar_lo': 30.071,
#      'bar_hi': 30.072,
#      'bar_lo_at': 1711576098,
#      'ts': 1711576140},
#     {'bar_absolute': 30.041,
#      'bar_hi_at': 1711576159,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.069,
#      'arch_int': 60,
#      'bar_lo': 30.069,
#      'bar_hi': 30.072,
#      'bar_lo_at': 1711576190,
#      'ts': 1711576200},
#     {'bar_absolute': 30.041,
#      'bar_hi_at': 1711576220,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.069,
#      'arch_int': 60,
#      'bar_lo': 30.069,
#      'bar_hi': 30.071,
#      'bar_lo_at': 1711576251,
#      'ts': 1711576260},
#     {'bar_absolute': 30.039,
#      'bar_hi_at': 1711576281,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.067,
#      'arch_int': 60,
#      'bar_lo': 30.067,
#      'bar_hi': 30.068,
#      'bar_lo_at': 1711576312,
#      'ts': 1711576320},
#     {'bar_absolute': 30.041,
#      'bar_hi_at': 1711576373,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.069,
#      'arch_int': 60,
#      'bar_lo': 30.067,
#      'bar_hi': 30.069,
#      'bar_lo_at': 1711576342,
#      'ts': 1711576380},
#     {'bar_absolute': 30.043,
#      'bar_hi_at': 1711576434,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.071,
#      'arch_int': 60,
#      'bar_lo': 30.069,
#      'bar_hi': 30.071,
#      'bar_lo_at': 1711576403,
#      'ts': 1711576440},
#     {'bar_absolute': 30.043,
#      'bar_hi_at': 1711576495,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.071,
#      'arch_int': 60,
#      'bar_lo': 30.069,
#      'bar_hi': 30.071,
#      'bar_lo_at': 1711576464,
#      'ts': 1711576500}],
#    'sensor_type': 242,
#    'data_structure_type': 13}],
#  'generated_at': 1711576549,
#  'station_id': 81211}
