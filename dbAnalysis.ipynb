# %%
import pandas as pd
import openpyxl
import datetime

# %%
filePath = ('/Users/jameshayes/downloads/')
fileName = ('CompleteWeatherRecordsExport1.xlsx')
excelName = filePath + fileName
df = pd.read_excel(excelName)
pd.set_option('display.max_rows', 150)
#df.describe()

# %%
years = range(1978,2024)
months = range(1,13)

for month in months:
    for year in years:
        filt = (df['Year'] == year) & (df['Month'] == month) & (df['LowTemp'] <= 0)
        q = df.loc[filt]
        if not q.empty:
            q.drop(q.index[0])
            display(q)
# Out:
#      Rain  HiTemp  LowTemp  Year  Month  Day
# 131   NaN    22.0     -4.0  1981      1    9
# 133   NaN    20.0      0.0  1981      1   11
# 135   NaN    19.0     -2.0  1981      1   13
#      Rain  HiTemp  LowTemp  Year  Month  Day
# 231   NaN    37.0     -3.0  1982      1   16
# 232   NaN    -3.0    -15.0  1982      1   17
# 233   NaN    17.0    -15.0  1982      1   18
#      Rain  HiTemp  LowTemp  Year  Month  Day
# 739   NaN    20.0     -1.0  1985      1   20
# 740   NaN     5.0     -3.0  1985      1   21
#       Rain  HiTemp  LowTemp  Year  Month  Day
# 3190  0.47    35.0     -1.0  1994      1   18
# 3191   NaN    17.0     -5.0  1994      1   19
# 3192  0.01    17.0     -1.0  1994      1   20
# 3193   NaN    31.0     -2.0  1994      1   21
#        Rain  HiTemp  LowTemp  Year  Month  Day
# 11453   0.0    20.2     -2.3  2018      1    7
#       Rain  HiTemp  LowTemp  Year  Month  Day
# 3596   NaN    20.0      0.0  1996      2    4
# 3597   NaN    24.0     -5.0  1996      2    5
# ...

# %%
import datetime

def datestdtojd (stddate):
    fmt='%Y-%m-%d'
    sdtdate = datetime.datetime.strptime(stddate, fmt)
    sdtdate = sdtdate.timetuple()
    jdate = sdtdate.tm_yday
    return(jdate)

file_load = (input("date: yyyy-m-dd\n"))

datestdtojd(file_load)

# %%
import math
from statistics import mean 

j = [115,109,103,142,118,108,106,102,96,105,109,97,91,97,107,83,101,94,103,76,89,87,94,106,115,101,83,101,92,108,93,89]
y = [309,312,321,315,306,298,314,321,308,312,323,311,331,304,330,316,312,292,327,314,308,305,320,282,295,287,293,306,308,308]
mean_julian_date = mean(y)
print(mean_julian_date)
# Out:
# 309.6
