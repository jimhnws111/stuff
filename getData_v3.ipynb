# %%
import json
import urllib
import requests
import csv
import re

# %%
#urltest = 'https://api.synopticdata.com/v2/stations/latest?token=146a1e25358f48f0a9d83a9a0d55e05c&state=ca&network=1,2&minmax=1&minmaxtype=local&units=english&within=60&vars=air_temp'
#urltest = 'https://api.synopticdata.com/v2/stations/latest?token=demotoken&bbox=-125,24.5,-66.95,49.35&country=us&network=1,2&minmax=1&minmaxtype=utc&units=english&within=60&vars=air_temp'
#urltest = 'https://api.synopticdata.com/v2/stations/latest?token=146a1e25358f48f0a9d83a9a0d55e05c&bbox=-125,24.5,-66.95,49.35&country=us&network=1,2&minmax=1&minmaxtype=utc&units=english&within=60&vars=air_temp'
urltest = 'https://api.synopticdata.com/v2/stations/latest?token=146a1e25358f48f0a9d83a9a0d55e05c&bbox=-125,24.5,-66.95,49.35&country=us&network=1,2,26,123&minmax=1&minmaxtype=utc&units=english&within=60&vars=air_temp&showemptystations=0'

r =  requests.get(urltest)
r.encoding = 'utf-8'
print (r.json())
print (r.encoding)
print (r.headers)

with open('/Users/jameshayes/synoptic.json','w') as fd:
#with open('home/ec2-user/synoptic.json')    
     json.dump(r.json(), fd)
# Out:
# {'UNITS': {'air_temp': 'Fahrenheit'}, 'QC_SUMMARY': {'QC_SHORTNAMES': {'1': 'sl_range_check'}, 'QC_CHECKS_APPLIED': ['sl_range_check'], 'PERCENT_OF_TOTAL_OBSERVATIONS_FLAGGED': 0.0, 'QC_SOURCENAMES': {'1': 'SynopticLabs'}, 'TOTAL_OBSERVATIONS_FLAGGED': 0.0, 'QC_NAMES': {'1': 'SynopticLabs Range Check'}}, 'STATION': [{'STATUS': 'ACTIVE', 'MNET_ID': '1', 'PERIOD_OF_RECORD': {'start': '1997-01-01T00:00:00Z', 'end': '2022-11-22T15:35:00Z'}, 'ELEVATION': '4226', 'NAME': 'Salt Lake City, Salt Lake City International Airport', 'STID': 'KSLC', 'SENSOR_VARIABLES': {'air_temp': {'air_temp_value_1': {'period_of_record': {'start': '', 'end': ''}}}}, 'ELEV_DEM': '4235.6', 'LONGITUDE': '-111.96503', 'UNITS': {'position': 'ft', 'elevation': 'ft'}, 'STATE': 'UT', 'OBSERVATIONS': {'air_temp_value_1': {'date_time': '2022-11-22T16:35:00Z', 'value': 32.0}}, 'RESTRICTED': False, 'QC_FLAGGED': False, 'LATITUDE': '40.77069', 'TIMEZONE': 'America/Denver', 'ID': '53', 'MINMAX': {'air_temp_value_1': {'dates': ['2022-11-22'], 'datetime_max_utc': ['2022-11-22T00:25:00'], 'value_min_utc': [24.08], 'value_max_utc': [35.6], 'datetime_timezone': 'utc', 'datetime_min_utc': ['2022-11-22T14:40:00']}}}, {'STATUS': 'ACTIVE', 'MNET_ID': '1', 'PERIOD_OF_RECORD': {'start': '1997-01-01T00:00:00Z', 'end': '2022-11-22T15:35:00Z'}, 'ELEVATION': '4596', 'NAME': 'Salt Lake City, Salt Lake City Municipal 2 Airport', 'STID': 'KU42', 'SENSOR_VARIABLES': {'air_temp': {'air_temp_value_1': {'period_of_record': {'start': '', 'end': ''}}}}, 'ELEV_DEM': '4603', 'LONGITUDE': '-111.99016', 'UNITS': {'position': 'ft', 'elevation': 'ft'}, 'STATE': 'UT', 'OBSERVATIONS': {'air_temp_value_1': {'date_time': '2022-11-22T16:35:00Z', 'value': 29.66}}, 'RESTRICTED': False, 'QC_FLAGGED': False, 'LATITUDE': '40.61960', 'TIMEZONE': 'America/Denver', 'ID': '54', 'MINMAX': {'air_temp_value_1': {'dates': ['2022-11-22'], 'datetime_max_utc': ['2022-11-22T01:15:00'], 'value_min_utc': [20.12], 'value_max_utc': [31.28], 'datetime_timezone': 'utc', 'datetime_min_utc': ['2022-11-22T14:15:00']}}}, {'STATUS': 'ACTIVE', 'MNET_ID': '1', 'PERIOD_OF_RECORD': {'start': '1997-01-01T00:00:00Z', 'end': '2022-11-22T14:55:00Z'}, 'ELEVATION': '4783', 'NAME': 'Hill Air Force Base', 'STID': 'KHIF', 'SENSOR_VARIABLES': {'air_temp': {'air_temp_value_1': {'period_of_record': {'start': '', 'end': ''}}}}, 'ELEV_DEM': '4799.9', 'LONGITUDE': '-111.96229', 'UNITS': {'position': 'ft', 'elevation': 'ft'}, 'STATE': 'UT', 'OBSERVATIONS': {'air_temp_value_1': {'date_time': '2022-11-22T15:55:00Z', 'value': 27.86}}, 'RESTRICTED': False, 'QC_FLAGGED': False, 'LATITUDE': '41.11112', 'TIMEZONE': 'America/Denver', 'ID': '55', 'MINMAX': {'air_temp_value_1': {'dates': ['2022-11-22'], 'datetime_max_utc': ['2022-11-22T00:55:00'], 'value_min_utc': [23.18], 'value_max_utc': [30.74], 'datetime_timezone': 'utc', 'datetime_min_utc': ['2022-11-22T13:55:00']}}}, {'STATUS': 'ACTIVE', 'MNET_ID': '1', 'PERIOD_OF_RECORD': {'start': '1997-01-01T00:00:00Z', 'end': '2022-11-22T15:35:00Z'}, 'ELEVATION': '4440', 'NAME': 'Ogden-Hinckley Airport', 'STID': 'KOGD', 'SENSOR_VARIABLES': {'air_temp': {'air_temp_value_1': {'period_of_record': {'start': '', 'end': ''}}}}, 'ELEV_DEM': '4452.1', 'LONGITUDE': '-112.01681', 'UNITS': {'position': 'ft', 'elevation': 'ft'}, 'STATE': 'UT', 'OBSERVATIONS': {'air_temp_value_1': {'date_time': '2022-11-22T16:35:00Z', 'value': 30.2}}, 'RESTRICTED': False, 'QC_FLAGGED': False, 'LATITUDE': '41.19406', 'TIMEZONE': 'America/Denver', 'ID': '56', 'MINMAX': {'air_temp_value_1': {'dates': ['2022-11-22'], 'datetime_max_utc': ['2022-11-22T00:30:00'], 'value_min_utc': [24.08], 'value_max_utc': [35.6], 'datetime_timezone': 'utc', 'datetime_min_utc': ['2022-11-22T12:55:00']}}}, {'STATUS': 'ACTIVE', 'MNET_ID': '1', 'PERIOD_OF_RECORD': {'start': '1997-01-01T00:00:00Z', 'end': '2022-11-22T15:10:00Z'}, 'ELEVATION': '4230', 'NAME': 'Brigham City Regional Airport', 'STID': 'KBMC', 'SENSOR_VARIABLES': {'air_temp': {'air_temp_value_1': {'period_of_re ...
# utf-8
# {'Date': 'Tue, 22 Nov 2022 16:45:32 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'nginx', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Headers': 'x-requested-with', 'Access-Control-Allow-Methods': 'POST, GET, OPTIONS', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip'}
