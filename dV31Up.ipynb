# %%
import calcOneDay
import getDays
from datetime import datetime, timedelta
import calcTimeNow
import daysAndDates
import logging
import checkDST

def logdV3():
    
    """Set up logging for this script"""
    
    logger = logging.getLogger(__name__)
    logger.setLevel(logging.DEBUG)
    formatter = logging.Formatter('%(levelname)s:%(name)s:%(message)s')
    #file_handler = logging.FileHandler('/home/ec2-user/davisPMUpdate.log')
    file_handler = logging.FileHandler('/Users/jameshayes/Sites/dV3Up.log')
    file_handler.setFormatter(formatter)
    logger.addHandler(file_handler)

# %%
import getDays
from datetime import datetime, timedelta
import calcTimeNow
import daysAndDatesNew
import checkDST
from dataFromDavis import dataFromDavis
from getAndStore import getAndStore
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
from dateutil.tz import tzutc, tzlocal
import pytz

def timesAndDates():
    
    """Calculate the time and date for end of day calculations
    First determine whether we are in DST or not"""

    # Check DST setting
    isDST = checkDST.checkDST()
    print(isDST)

    if isDST == 1:
        now = datetime.now()
        end = int(datetime.timestamp(now))
        start = (end - 59400)
        start = str(start)
        end = str(end)
        
    else:
        now = datetime.now()
        end = int(datetime.timestamp(now))
        start = (end - 59400)
        start = str(start)
        end = str(end)    

    dayInfo = daysAndDatesNew.daysAndDatesNew()
    month, month_num, date, year = dayInfo[0], dayInfo[1], dayInfo[2], dayInfo[3]
    yesterday = int(dayInfo[4])
    nextDay = int(dayInfo[5])
    month_num = int(month_num)
    date = int(date)
        
    return(start, end, month, month_num, date, year, yesterday, nextDay)

# %%
import collections
import hashlib
import hmac
import time
from datetime import datetime
import requests
import json
import dataFile
import getData
import checkDST

#
# Get the start and end times, depending on product
#

def timeCheck():

    """make sure the time is correct for the product"""

    now = datetime.now()
    x = now.strftime("%Y-%m-%d")
    print("This script started at:", now)

    t1 = ' 17:00'
    t2 = ' 18:00'
    time1 = x + t1
    time2 = x + t2
    val1 = datetime.strptime(time1, "%Y-%m-%d %H:%M")
    val2 = datetime.strptime(time2, "%Y-%m-%d %H:%M")

    if val1 < now < val2:
        end = int(datetime.timestamp(now))
        start = (end - 59400)
        start = str(start)
        end = str(end)    
        
    else:
        pass

    return(start, end)
    

def dataFromDavis():
    
    """Get Davis data via the API""" 
       
    parameters = {
      "api-key": "vy8jbrjsxlbwgojepq3vfyfqfywyhvbd", 
      "api-secret": "sdqfm6wdfy9w0pqp2vdka38o6b4vcsvc",
      "station-id": 81211, 
      "end-timestamp": end,
      "start-timestamp": start,
      "t": int(time.time())
    }

    
    parameters = collections.OrderedDict(sorted(parameters.items()))

   #for key in parameters:
   #     print("Parameter name: \"{}\" has value \"{}\"".format(key, parameters[key]))

    apiSecret = parameters["api-secret"];
    parameters.pop("api-secret", None);

    data = ""
    for key in parameters:
        data = data + key + str(parameters[key])

    #logger.info('Data string to hash is: \"{}\"'.format(data))   


    apiSignature = hmac.new(
      apiSecret.encode('utf-8'),
      data.encode('utf-8'),
      hashlib.sha256
    ).hexdigest()

    #logger.info('API Signature is: \"{}\"'.format(apiSignature))

    # Building the URL to get the station
    
    first_part = ('https://api.weatherlink.com/v2/historic/81211?')
    api_key = ('api-key=vy8jbrjsxlbwgojepq3vfyfqfywyhvbd')
    add_apisig = ('&api-signature=')
    add_t = ('&t='+ str(int(time.time())))

    start1 = "&start-timestamp=" + start
    end1 = "&end-timestamp=" + end

    URLfinal = (first_part + api_key + add_t + start1 + end1 + add_apisig + apiSignature)

    r =  requests.get(URLfinal)
    davisAPI = (r.json())
    return(davisAPI)

dataFromDavis()
# Out:
# {'station_id_uuid': '245f6069-3309-4f78-aa0e-8f97d4e5d6ec',
#  'sensors': [{'lsid': 274372,
#    'data': [{'temp_in_lo_at': 1711084112,
#      'arch_int': 60,
#      'temp_in_hi': 73.5,
#      'temp_in_hi_at': 1711084082,
#      'hum_in_hi': 22.1,
#      'temp_in_last': 73.3,
#      'temp_in_lo': 73.3,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.3,
#      'hum_in_lo_at': 1711084082,
#      'tz_offset': -14400,
#      'heat_index_in': 70.2,
#      'hum_in_hi_at': 1711084082,
#      'ts': 1711084140},
#     {'temp_in_lo_at': 1711084172,
#      'arch_int': 60,
#      'temp_in_hi': 73.5,
#      'temp_in_hi_at': 1711084142,
#      'hum_in_hi': 22.3,
#      'temp_in_last': 73.3,
#      'temp_in_lo': 73.3,
#      'hum_in_lo': 22.2,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.4,
#      'hum_in_lo_at': 1711084172,
#      'tz_offset': -14400,
#      'heat_index_in': 70.2,
#      'hum_in_hi_at': 1711084142,
#      'ts': 1711084200},
#     {'temp_in_lo_at': 1711084202,
#      'arch_int': 60,
#      'temp_in_hi': 73.4,
#      'temp_in_hi_at': 1711084202,
#      'hum_in_hi': 22.4,
#      'temp_in_last': 73.4,
#      'temp_in_lo': 73.4,
#      'hum_in_lo': 22.4,
#      'hum_in_last': 22.4,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711084202,
#      'tz_offset': -14400,
#      'heat_index_in': 70.3,
#      'hum_in_hi_at': 1711084202,
#      'ts': 1711084260},
#     {'temp_in_lo_at': 1711084292,
#      'arch_int': 60,
#      'temp_in_hi': 73.5,
#      'temp_in_hi_at': 1711084262,
#      'hum_in_hi': 22.3,
#      'temp_in_last': 73.4,
#      'temp_in_lo': 73.4,
#      'hum_in_lo': 22.3,
#      'hum_in_last': 22.3,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711084262,
#      'tz_offset': -14400,
#      'heat_index_in': 70.3,
#      'hum_in_hi_at': 1711084262,
#      'ts': 1711084320},
#     {'temp_in_lo_at': 1711084352,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711084322,
#      'hum_in_hi': 22.6,
#      'temp_in_last': 73.4,
#      'temp_in_lo': 73.4,
#      'hum_in_lo': 22.3,
#      'hum_in_last': 22.3,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711084352,
#      'tz_offset': -14400,
#      'heat_index_in': 70.3,
#      'hum_in_hi_at': 1711084322,
#      'ts': 1711084380},
#     {'temp_in_lo_at': 1711084382,
#      'arch_int': 60,
#      'temp_in_hi': 73.5,
#      'temp_in_hi_at': 1711084382,
#      'hum_in_hi': 22.5,
#      'temp_in_last': 73.5,
#      'temp_in_lo': 73.5,
#      'hum_in_lo': 22.4,
#      'hum_in_last': 22.5,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711084382,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711084412,
#      'ts': 1711084440},
#     {'temp_in_lo_at': 1711084442,
#      'arch_int': 60,
#      'temp_in_hi': 73.5,
#      'temp_in_hi_at': 1711084472,
#      'hum_in_hi': 22.3,
#      'temp_in_last': 73.5,
#      'temp_in_lo': 73.4,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.4,
#      'hum_in_lo_at': 1711084472,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711084442,
#      'ts': 1711084500},
#     {'temp_in_lo_at': 1711084502,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711084532,
#      'hum_in_hi': 22.4,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.5,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.4,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711084502,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711084532,
#      'ts': 1711084560},
#     {'temp_in_lo_at': 1711084562,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711084562,
#      'hum_in_hi': 22.4,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.4,
#      'hum_in_last': 22.4,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711084562,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711084562,
#      'ts': 1711084620},
#     {'temp_in_lo_at': 1711084622,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711084652,
#      'hum_in_hi': 22.5,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.5,
#      'hum_in_lo': 22.3,
#      'hum_in_last': 22.5,
#      'dew_point_in': 33,
#      'hum_in_lo_at': 1711084622,
#      'tz_offset': -14400,
#      'heat_index_in': 70.7,
#      'hum_in_hi_at': 1711084652,
#      'ts': 1711084680},
#     {'temp_in_lo_at': 1711084682,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711084682,
#      'hum_in_hi': 22.4,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.2,
#      'hum_in_last': 22.4,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711084682,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711084712,
#      'ts': 1711084740},
#     {'temp_in_lo_at': 1711084742,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711084742,
#      'hum_in_hi': 22.4,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.2,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711084772,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711084742,
#      'ts': 1711084800},
#     {'temp_in_lo_at': 1711084802,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711084832,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.2,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711084802,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711084802,
#      'ts': 1711084860},
#     {'temp_in_lo_at': 1711084862,
#      'arch_int': 60,
#      'temp_in_hi': 73.5,
#      'temp_in_hi_at': 1711084862,
#      'hum_in_hi': 22.3,
#      'temp_in_last': 73.5,
#      'temp_in_lo': 73.5,
#      'hum_in_lo': 22.3,
#      'hum_in_last': 22.3,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711084862,
#      'tz_offset': -14400,
#      'heat_index_in': 70.5,
#      'hum_in_hi_at': 1711084862,
#      'ts': 1711084920},
#     {'temp_in_lo_at': 1711084922,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711084952,
#      'hum_in_hi': 22.1,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.5,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711084922,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711084922,
#      'ts': 1711084980},
#     {'temp_in_lo_at': 1711084982,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711085012,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.5,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711084982,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711085012,
#      'ts': 1711085040},
#     {'temp_in_lo_at': 1711085042,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711085042,
#      'hum_in_hi': 22.1,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711085042,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711085042,
#      'ts': 1711085100},
#     {'temp_in_lo_at': 1711085102,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711085132,
#      'hum_in_hi': 22.3,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.5,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711085132,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711085102,
#      'ts': 1711085160},
#     {'temp_in_lo_at': 1711085162,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711085192,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.5,
#      'hum_in_lo': 22,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711085162,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711085192,
#      'ts': 1711085220},
#     {'temp_in_lo_at': 1711085252,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711085222,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711085252,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711085222,
#      'ts': 1711085280},
#     {'temp_in_lo_at': 1711085282,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711085282,
#      'hum_in_hi': 22.1,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.4,
#      'hum_in_lo_at': 1711085312,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711085282,
#      'ts': 1711085340},
#     {'temp_in_lo_at': 1711085342,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711085342,
#      'hum_in_hi': 22.1,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711085342,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711085342,
#      'ts': 1711085400},
#     {'temp_in_lo_at': 1711085403,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711085433,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.8,
#      'temp_in_lo': 73.5,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711085403,
#      'tz_offset': -14400,
#      'heat_index_in': 70.9,
#      'hum_in_hi_at': 1711085433,
#      'ts': 1711085460},
#     {'temp_in_lo_at': 1711085463,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711085493,
#      'hum_in_hi': 22.4,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.5,
#      'hum_in_lo': 22,
#      'hum_in_last': 22.4,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711085463,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711085493,
#      'ts': 1711085520},
#     {'temp_in_lo_at': 1711085553,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711085523,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711085553,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711085523,
#      'ts': 1711085580},
#     {'temp_in_lo_at': 1711085613,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711085583,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711085613,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711085583,
#      'ts': 1711085640},
#     {'temp_in_lo_at': 1711085643,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711085643,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711085643,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711085673,
#      'ts': 1711085700},
#     {'temp_in_lo_at': 1711085703,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711085733,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711085703,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711085733,
#      'ts': 1711085760},
#     {'temp_in_lo_at': 1711085793,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711085763,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.2,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711085763,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711085763,
#      'ts': 1711085820},
#     {'temp_in_lo_at': 1711085823,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711085853,
#      'hum_in_hi': 22.1,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.5,
#      'hum_in_lo': 22,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711085823,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711085853,
#      'ts': 1711085880},
#     {'temp_in_lo_at': 1711085883,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711085913,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.2,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711085883,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711085883,
#      'ts': 1711085940},
#     {'temp_in_lo_at': 1711085973,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711085943,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711085973,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711085943,
#      'ts': 1711086000},
#     {'temp_in_lo_at': 1711086033,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711086003,
#      'hum_in_hi': 22.3,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22.2,
#      'hum_in_last': 22.3,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711086003,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711086033,
#      'ts': 1711086060},
#     {'temp_in_lo_at': 1711086063,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711086093,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711086063,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711086093,
#      'ts': 1711086120},
#     {'temp_in_lo_at': 1711086123,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711086123,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22.2,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711086123,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711086123,
#      'ts': 1711086180},
#     {'temp_in_lo_at': 1711086213,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711086183,
#      'hum_in_hi': 22.3,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711086213,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711086183,
#      'ts': 1711086240},
#     {'temp_in_lo_at': 1711086243,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711086243,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22.2,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711086243,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711086243,
#      'ts': 1711086300},
#     {'temp_in_lo_at': 1711086303,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711086333,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711086333,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711086303,
#      'ts': 1711086360},
#     {'temp_in_lo_at': 1711086393,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711086363,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22.2,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711086363,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711086363,
#      'ts': 1711086420},
#     {'temp_in_lo_at': 1711086453,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711086423,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711086423,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711086453,
#      'ts': 1711086480},
#     {'temp_in_lo_at': 1711086483,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711086513,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711086483,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711086513,
#      'ts': 1711086540},
#     {'temp_in_lo_at': 1711086543,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711086543,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.8,
#      'temp_in_lo': 73.8,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711086543,
#      'tz_offset': -14400,
#      'heat_index_in': 70.9,
#      'hum_in_hi_at': 1711086573,
#      'ts': 1711086600},
#     {'temp_in_lo_at': 1711086603,
#      'arch_int': 60,
#      'temp_in_hi': 73.7,
#      'temp_in_hi_at': 1711086603,
#      'hum_in_hi': 22,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 22,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711086603,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711086633,
#      'ts': 1711086660},
#     {'temp_in_lo_at': 1711086663,
#      'arch_int': 60,
#      'temp_in_hi': 73.6,
#      'temp_in_hi_at': 1711086663,
#      'hum_in_hi': 22,
#      'temp_in_last': 73.6,
#      'temp_in_lo': 73.6,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 22,
#      'dew_point_in': 32.4,
#      'hum_in_lo_at': 1711086663,
#      'tz_offset': -14400,
#      'heat_index_in': 70.6,
#      'hum_in_hi_at': 1711086693,
#      'ts': 1711086720},
#     {'temp_in_lo_at': 1711086753,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711086723,
#      'hum_in_hi': 22.1,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711086723,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711086753,
#      'ts': 1711086780},
#     {'temp_in_lo_at': 1711086813,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711086783,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711086783,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711086813,
#      'ts': 1711086840},
#     {'temp_in_lo_at': 1711086873,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711086843,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711086873,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711086843,
#      'ts': 1711086900},
#     {'temp_in_lo_at': 1711086903,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711086933,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.8,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711086903,
#      'tz_offset': -14400,
#      'heat_index_in': 70.9,
#      'hum_in_hi_at': 1711086933,
#      'ts': 1711086960},
#     {'temp_in_lo_at': 1711086993,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711086963,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711086963,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711086993,
#      'ts': 1711087020},
#     {'temp_in_lo_at': 1711087023,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711087053,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711087053,
#      'tz_offset': -14400,
#      'heat_index_in': 71.1,
#      'hum_in_hi_at': 1711087023,
#      'ts': 1711087080},
#     {'temp_in_lo_at': 1711087083,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711087113,
#      'hum_in_hi': 22.1,
#      'temp_in_last': 73.8,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711087083,
#      'tz_offset': -14400,
#      'heat_index_in': 70.9,
#      'hum_in_hi_at': 1711087083,
#      'ts': 1711087140},
#     {'temp_in_lo_at': 1711087143,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711087143,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 22.2,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711087143,
#      'tz_offset': -14400,
#      'heat_index_in': 71.1,
#      'hum_in_hi_at': 1711087143,
#      'ts': 1711087200},
#     {'temp_in_lo_at': 1711087203,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711087233,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711087233,
#      'tz_offset': -14400,
#      'heat_index_in': 71.1,
#      'hum_in_hi_at': 1711087203,
#      'ts': 1711087260},
#     {'temp_in_lo_at': 1711087263,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711087294,
#      'hum_in_hi': 22.1,
#      'temp_in_last': 74,
#      'temp_in_lo': 73.8,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711087294,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711087263,
#      'ts': 1711087320},
#     {'temp_in_lo_at': 1711087324,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711087324,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711087354,
#      'tz_offset': -14400,
#      'heat_index_in': 71.1,
#      'hum_in_hi_at': 1711087324,
#      'ts': 1711087380},
#     {'temp_in_lo_at': 1711087384,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711087384,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 22.2,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711087384,
#      'tz_offset': -14400,
#      'heat_index_in': 71.1,
#      'hum_in_hi_at': 1711087384,
#      'ts': 1711087440},
#     {'temp_in_lo_at': 1711087474,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711087444,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711087444,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711087474,
#      'ts': 1711087500},
#     {'temp_in_lo_at': 1711087534,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711087504,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711087534,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711087504,
#      'ts': 1711087560},
#     {'temp_in_lo_at': 1711087564,
#      'arch_int': 60,
#      'temp_in_hi': 73.8,
#      'temp_in_hi_at': 1711087564,
#      'hum_in_hi': 22.1,
#      'temp_in_last': 73.8,
#      'temp_in_lo': 73.8,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711087594,
#      'tz_offset': -14400,
#      'heat_index_in': 70.9,
#      'hum_in_hi_at': 1711087564,
#      'ts': 1711087620},
#     {'temp_in_lo_at': 1711087654,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711087624,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 73.8,
#      'temp_in_lo': 73.8,
#      'hum_in_lo': 21.7,
#      'hum_in_last': 21.7,
#      'dew_point_in': 32.3,
#      'hum_in_lo_at': 1711087654,
#      'tz_offset': -14400,
#      'heat_index_in': 70.9,
#      'hum_in_hi_at': 1711087624,
#      'ts': 1711087680},
#     {'temp_in_lo_at': 1711087714,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711087684,
#      'hum_in_hi': 22,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711087684,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711087684,
#      'ts': 1711087740},
#     {'temp_in_lo_at': 1711087744,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711087774,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.8,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711087744,
#      'tz_offset': -14400,
#      'heat_index_in': 71.1,
#      'hum_in_hi_at': 1711087774,
#      'ts': 1711087800},
#     {'temp_in_lo_at': 1711087804,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711087834,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 74,
#      'temp_in_lo': 73.8,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 22.2,
#      'dew_point_in': 33,
#      'hum_in_lo_at': 1711087804,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711087834,
#      'ts': 1711087860},
#     {'temp_in_lo_at': 1711087864,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711087864,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.7,
#      'hum_in_last': 21.7,
#      'dew_point_in': 32.4,
#      'hum_in_lo_at': 1711087894,
#      'tz_offset': -14400,
#      'heat_index_in': 71,
#      'hum_in_hi_at': 1711087864,
#      'ts': 1711087920},
#     {'temp_in_lo_at': 1711087954,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711087924,
#      'hum_in_hi': 22,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 22,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711087924,
#      'tz_offset': -14400,
#      'heat_index_in': 71.1,
#      'hum_in_hi_at': 1711087954,
#      'ts': 1711087980},
#     {'temp_in_lo_at': 1711087984,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711087984,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 74,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711087984,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711087984,
#      'ts': 1711088040},
#     {'temp_in_lo_at': 1711088044,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711088044,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711088044,
#      'tz_offset': -14400,
#      'heat_index_in': 71,
#      'hum_in_hi_at': 1711088044,
#      'ts': 1711088100},
#     {'temp_in_lo_at': 1711088134,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711088104,
#      'hum_in_hi': 22,
#      'temp_in_last': 73.8,
#      'temp_in_lo': 73.8,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711088134,
#      'tz_offset': -14400,
#      'heat_index_in': 70.9,
#      'hum_in_hi_at': 1711088104,
#      'ts': 1711088160},
#     {'temp_in_lo_at': 1711088194,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711088164,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 22.2,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711088164,
#      'tz_offset': -14400,
#      'heat_index_in': 71.1,
#      'hum_in_hi_at': 1711088194,
#      'ts': 1711088220},
#     {'temp_in_lo_at': 1711088254,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711088224,
#      'hum_in_hi': 22,
#      'temp_in_last': 73.7,
#      'temp_in_lo': 73.7,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711088224,
#      'tz_offset': -14400,
#      'heat_index_in': 70.8,
#      'hum_in_hi_at': 1711088224,
#      'ts': 1711088280},
#     {'temp_in_lo_at': 1711088314,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711088284,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711088284,
#      'tz_offset': -14400,
#      'heat_index_in': 71,
#      'hum_in_hi_at': 1711088314,
#      'ts': 1711088340},
#     {'temp_in_lo_at': 1711088344,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711088374,
#      'hum_in_hi': 22,
#      'temp_in_last': 74,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 22,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711088344,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711088374,
#      'ts': 1711088400},
#     {'temp_in_lo_at': 1711088404,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711088404,
#      'hum_in_hi': 22,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711088404,
#      'tz_offset': -14400,
#      'heat_index_in': 71.1,
#      'hum_in_hi_at': 1711088404,
#      'ts': 1711088460},
#     {'temp_in_lo_at': 1711088464,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711088494,
#      'hum_in_hi': 22,
#      'temp_in_last': 74,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711088494,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711088464,
#      'ts': 1711088520},
#     {'temp_in_lo_at': 1711088524,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711088554,
#      'hum_in_hi': 22.2,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 22.1,
#      'hum_in_last': 22.1,
#      'dew_point_in': 33,
#      'hum_in_lo_at': 1711088554,
#      'tz_offset': -14400,
#      'heat_index_in': 71.4,
#      'hum_in_hi_at': 1711088524,
#      'ts': 1711088580},
#     {'temp_in_lo_at': 1711088614,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711088584,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 73.8,
#      'temp_in_lo': 73.8,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711088584,
#      'tz_offset': -14400,
#      'heat_index_in': 70.9,
#      'hum_in_hi_at': 1711088584,
#      'ts': 1711088640},
#     {'temp_in_lo_at': 1711088644,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711088644,
#      'hum_in_hi': 22,
#      'temp_in_last': 74,
#      'temp_in_lo': 74,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711088644,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711088644,
#      'ts': 1711088700},
#     {'temp_in_lo_at': 1711088734,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711088704,
#      'hum_in_hi': 22,
#      'temp_in_last': 74,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711088734,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711088704,
#      'ts': 1711088760},
#     {'temp_in_lo_at': 1711088764,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711088794,
#      'hum_in_hi': 22,
#      'temp_in_last': 74,
#      'temp_in_lo': 73.8,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 22,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711088764,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711088794,
#      'ts': 1711088820},
#     {'temp_in_lo_at': 1711088854,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711088824,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711088824,
#      'tz_offset': -14400,
#      'heat_index_in': 71,
#      'hum_in_hi_at': 1711088824,
#      'ts': 1711088880},
#     {'temp_in_lo_at': 1711088884,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711088914,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711088884,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711088884,
#      'ts': 1711088940},
#     {'temp_in_lo_at': 1711088944,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711088944,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711088944,
#      'tz_offset': -14400,
#      'heat_index_in': 71,
#      'hum_in_hi_at': 1711088944,
#      'ts': 1711089000},
#     {'temp_in_lo_at': 1711089004,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711089034,
#      'hum_in_hi': 22,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 22,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711089004,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711089034,
#      'ts': 1711089060},
#     {'temp_in_lo_at': 1711089064,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711089064,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74.1,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711089064,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711089064,
#      'ts': 1711089120},
#     {'temp_in_lo_at': 1711089124,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711089124,
#      'hum_in_hi': 22,
#      'temp_in_last': 74,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.8,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711089154,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711089124,
#      'ts': 1711089180},
#     {'temp_in_lo_at': 1711089215,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711089184,
#      'hum_in_hi': 21.7,
#      'temp_in_last': 74,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.6,
#      'hum_in_last': 21.6,
#      'dew_point_in': 32.3,
#      'hum_in_lo_at': 1711089215,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711089184,
#      'ts': 1711089240},
#     {'temp_in_lo_at': 1711089245,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711089275,
#      'hum_in_hi': 21.8,
#      'temp_in_last': 74,
#      'temp_in_lo': 73.8,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.8,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711089245,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711089245,
#      'ts': 1711089300},
#     {'temp_in_lo_at': 1711089335,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711089305,
#      'hum_in_hi': 21.8,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.8,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711089305,
#      'tz_offset': -14400,
#      'heat_index_in': 71,
#      'hum_in_hi_at': 1711089305,
#      'ts': 1711089360},
#     {'temp_in_lo_at': 1711089365,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711089365,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 74,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711089365,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711089395,
#      'ts': 1711089420},
#     {'temp_in_lo_at': 1711089425,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711089455,
#      'hum_in_hi': 22,
#      'temp_in_last': 74,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711089425,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711089425,
#      'ts': 1711089480},
#     {'temp_in_lo_at': 1711089485,
#      'arch_int': 60,
#      'temp_in_hi': 73.9,
#      'temp_in_hi_at': 1711089485,
#      'hum_in_hi': 22,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711089515,
#      'tz_offset': -14400,
#      'heat_index_in': 71,
#      'hum_in_hi_at': 1711089485,
#      'ts': 1711089540},
#     {'temp_in_lo_at': 1711089545,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711089545,
#      'hum_in_hi': 22,
#      'temp_in_last': 74,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711089575,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711089545,
#      'ts': 1711089600},
#     {'temp_in_lo_at': 1711089635,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711089605,
#      'hum_in_hi': 22,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711089605,
#      'tz_offset': -14400,
#      'heat_index_in': 71.1,
#      'hum_in_hi_at': 1711089605,
#      'ts': 1711089660},
#     {'temp_in_lo_at': 1711089665,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711089665,
#      'hum_in_hi': 21.8,
#      'temp_in_last': 74,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.8,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711089665,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711089665,
#      'ts': 1711089720},
#     {'temp_in_lo_at': 1711089725,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711089725,
#      'hum_in_hi': 22,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74.1,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711089725,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711089725,
#      'ts': 1711089780},
#     {'temp_in_lo_at': 1711089815,
#      'arch_int': 60,
#      'temp_in_hi': 74.2,
#      'temp_in_hi_at': 1711089785,
#      'hum_in_hi': 22,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74.1,
#      'hum_in_lo': 22,
#      'hum_in_last': 22,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711089785,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711089785,
#      'ts': 1711089840},
#     {'temp_in_lo_at': 1711089845,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711089845,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74.1,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711089845,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711089845,
#      'ts': 1711089900},
#     {'temp_in_lo_at': 1711089905,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711089905,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74.1,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711089905,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711089905,
#      'ts': 1711089960},
#     {'temp_in_lo_at': 1711089995,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711089965,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711089965,
#      'tz_offset': -14400,
#      'heat_index_in': 71,
#      'hum_in_hi_at': 1711089965,
#      'ts': 1711090020},
#     {'temp_in_lo_at': 1711090025,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711090025,
#      'hum_in_hi': 22,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74.1,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 22,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711090025,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711090055,
#      'ts': 1711090080},
#     {'temp_in_lo_at': 1711090115,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711090085,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 74,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711090085,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711090085,
#      'ts': 1711090140},
#     {'temp_in_lo_at': 1711090175,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711090145,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.8,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711090175,
#      'tz_offset': -14400,
#      'heat_index_in': 71,
#      'hum_in_hi_at': 1711090145,
#      'ts': 1711090200},
#     {'temp_in_lo_at': 1711090205,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711090205,
#      'hum_in_hi': 22,
#      'temp_in_last': 74,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 22,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711090205,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711090235,
#      'ts': 1711090260},
#     {'temp_in_lo_at': 1711090265,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711090295,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711090265,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711090295,
#      'ts': 1711090320},
#     {'temp_in_lo_at': 1711090355,
#      'arch_int': 60,
#      'temp_in_hi': 74.2,
#      'temp_in_hi_at': 1711090325,
#      'hum_in_hi': 22,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74.1,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711090355,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711090325,
#      'ts': 1711090380},
#     {'temp_in_lo_at': 1711090385,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711090415,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.8,
#      'hum_in_lo_at': 1711090385,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711090415,
#      'ts': 1711090440},
#     {'temp_in_lo_at': 1711090445,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711090445,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74.1,
#      'hum_in_lo': 21.6,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711090445,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711090475,
#      'ts': 1711090500},
#     {'temp_in_lo_at': 1711090505,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711090535,
#      'hum_in_hi': 21.8,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.6,
#      'hum_in_last': 21.6,
#      'dew_point_in': 32.4,
#      'hum_in_lo_at': 1711090535,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711090505,
#      'ts': 1711090560},
#     {'temp_in_lo_at': 1711090595,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711090565,
#      'hum_in_hi': 21.8,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.8,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711090565,
#      'tz_offset': -14400,
#      'heat_index_in': 71,
#      'hum_in_hi_at': 1711090565,
#      'ts': 1711090620},
#     {'temp_in_lo_at': 1711090625,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711090625,
#      'hum_in_hi': 21.8,
#      'temp_in_last': 74,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.8,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711090625,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711090625,
#      'ts': 1711090680},
#     {'temp_in_lo_at': 1711090685,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711090715,
#      'hum_in_hi': 21.8,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.7,
#      'hum_in_last': 21.7,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711090715,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711090685,
#      'ts': 1711090740},
#     {'temp_in_lo_at': 1711090745,
#      'arch_int': 60,
#      'temp_in_hi': 74.2,
#      'temp_in_hi_at': 1711090775,
#      'hum_in_hi': 22,
#      'temp_in_last': 74.2,
#      'temp_in_lo': 74.1,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 22,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711090745,
#      'tz_offset': -14400,
#      'heat_index_in': 71.5,
#      'hum_in_hi_at': 1711090775,
#      'ts': 1711090800},
#     {'temp_in_lo_at': 1711090805,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711090805,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 74,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711090805,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711090835,
#      'ts': 1711090860},
#     {'temp_in_lo_at': 1711090895,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711090865,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 74,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.8,
#      'dew_point_in': 32.6,
#      'hum_in_lo_at': 1711090895,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711090865,
#      'ts': 1711090920},
#     {'temp_in_lo_at': 1711090955,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711090925,
#      'hum_in_hi': 21.8,
#      'temp_in_last': 73.9,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.8,
#      'hum_in_last': 21.8,
#      'dew_point_in': 32.5,
#      'hum_in_lo_at': 1711090925,
#      'tz_offset': -14400,
#      'heat_index_in': 71,
#      'hum_in_hi_at': 1711090925,
#      'ts': 1711090980},
#     {'temp_in_lo_at': 1711090985,
#      'arch_int': 60,
#      'temp_in_hi': 74,
#      'temp_in_hi_at': 1711091015,
#      'hum_in_hi': 21.9,
#      'temp_in_last': 74,
#      'temp_in_lo': 73.9,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 21.9,
#      'dew_point_in': 32.7,
#      'hum_in_lo_at': 1711090985,
#      'tz_offset': -14400,
#      'heat_index_in': 71.2,
#      'hum_in_hi_at': 1711090985,
#      'ts': 1711091040},
#     {'temp_in_lo_at': 1711091045,
#      'arch_int': 60,
#      'temp_in_hi': 74.1,
#      'temp_in_hi_at': 1711091075,
#      'hum_in_hi': 22,
#      'temp_in_last': 74.1,
#      'temp_in_lo': 74,
#      'hum_in_lo': 21.9,
#      'hum_in_last': 22,
#      'dew_point_in': 32.9,
#      'hum_in_lo_at': 1711091045,
#      'tz_offset': -14400,
#      'heat_index_in': 71.3,
#      'hum_in_hi_at': 1711091075,
#      'ts': 1711091100},
#     {'temp_in_lo_at': 1711091136,
#      'arch_int': 60,
#      'temp_in_hi': 74,
# ...
#      'bar_lo': 30.323,
#      'bar_hi': 30.329,
#      'bar_lo_at': 1711139443,
#      'ts': 1711139460},
#     {'bar_absolute': 30.299,
#      'bar_hi_at': 1711139504,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.327,
#      'arch_int': 60,
#      'bar_lo': 30.326,
#      'bar_hi': 30.327,
#      'bar_lo_at': 1711139473,
#      'ts': 1711139520},
#     {'bar_absolute': 30.296,
#      'bar_hi_at': 1711139534,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.324,
#      'arch_int': 60,
#      'bar_lo': 30.324,
#      'bar_hi': 30.324,
#      'bar_lo_at': 1711139534,
#      'ts': 1711139580},
#     {'bar_absolute': 30.296,
#      'bar_hi_at': 1711139595,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.324,
#      'arch_int': 60,
#      'bar_lo': 30.324,
#      'bar_hi': 30.325,
#      'bar_lo_at': 1711139626,
#      'ts': 1711139640},
#     {'bar_absolute': 30.298,
#      'bar_hi_at': 1711139656,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.326,
#      'arch_int': 60,
#      'bar_lo': 30.326,
#      'bar_hi': 30.326,
#      'bar_lo_at': 1711139656,
#      'ts': 1711139700},
#     {'bar_absolute': 30.296,
#      'bar_hi_at': 1711139717,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.324,
#      'arch_int': 60,
#      'bar_lo': 30.324,
#      'bar_hi': 30.324,
#      'bar_lo_at': 1711139717,
#      'ts': 1711139760},
#     {'bar_absolute': 30.295,
#      'bar_hi_at': 1711139808,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.323,
#      'arch_int': 60,
#      'bar_lo': 30.322,
#      'bar_hi': 30.323,
#      'bar_lo_at': 1711139778,
#      'ts': 1711139820},
#     {'bar_absolute': 30.294,
#      'bar_hi_at': 1711139839,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.322,
#      'arch_int': 60,
#      'bar_lo': 30.322,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711139839,
#      'ts': 1711139880},
#     {'bar_absolute': 30.293,
#      'bar_hi_at': 1711139900,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.321,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.324,
#      'bar_lo_at': 1711139930,
#      'ts': 1711139940},
#     {'bar_absolute': 30.296,
#      'bar_hi_at': 1711139961,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.324,
#      'arch_int': 60,
#      'bar_lo': 30.324,
#      'bar_hi': 30.324,
#      'bar_lo_at': 1711139961,
#      'ts': 1711140000},
#     {'bar_absolute': 30.295,
#      'bar_hi_at': 1711140052,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.323,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.323,
#      'bar_lo_at': 1711140022,
#      'ts': 1711140060},
#     {'bar_absolute': 30.295,
#      'bar_hi_at': 1711140083,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.323,
#      'arch_int': 60,
#      'bar_lo': 30.323,
#      'bar_hi': 30.327,
#      'bar_lo_at': 1711140113,
#      'ts': 1711140120},
#     {'bar_absolute': 30.296,
#      'bar_hi_at': 1711140174,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.324,
#      'arch_int': 60,
#      'bar_lo': 30.322,
#      'bar_hi': 30.324,
#      'bar_lo_at': 1711140144,
#      'ts': 1711140180},
#     {'bar_absolute': 30.293,
#      'bar_hi_at': 1711140235,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.321,
#      'arch_int': 60,
#      'bar_lo': 30.318,
#      'bar_hi': 30.321,
#      'bar_lo_at': 1711140205,
#      'ts': 1711140240},
#     {'bar_absolute': 30.29,
#      'bar_hi_at': 1711140265,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.318,
#      'arch_int': 60,
#      'bar_lo': 30.318,
#      'bar_hi': 30.321,
#      'bar_lo_at': 1711140296,
#      'ts': 1711140300},
#     {'bar_absolute': 30.29,
#      'bar_hi_at': 1711140326,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.318,
#      'arch_int': 60,
#      'bar_lo': 30.318,
#      'bar_hi': 30.318,
#      'bar_lo_at': 1711140326,
#      'ts': 1711140360},
#     {'bar_absolute': 30.292,
#      'bar_hi_at': 1711140387,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.32,
#      'arch_int': 60,
#      'bar_lo': 30.32,
#      'bar_hi': 30.321,
#      'bar_lo_at': 1711140418,
#      'ts': 1711140420},
#     {'bar_absolute': 30.294,
#      'bar_hi_at': 1711140479,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.322,
#      'arch_int': 60,
#      'bar_lo': 30.318,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711140448,
#      'ts': 1711140480},
#     {'bar_absolute': 30.293,
#      'bar_hi_at': 1711140509,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.321,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711140540,
#      'ts': 1711140540},
#     {'bar_absolute': 30.292,
#      'bar_hi_at': 1711140570,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.32,
#      'arch_int': 60,
#      'bar_lo': 30.32,
#      'bar_hi': 30.32,
#      'bar_lo_at': 1711140570,
#      'ts': 1711140600},
#     {'bar_absolute': 30.29,
#      'bar_hi_at': 1711140631,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.318,
#      'arch_int': 60,
#      'bar_lo': 30.317,
#      'bar_hi': 30.318,
#      'bar_lo_at': 1711140601,
#      'ts': 1711140660},
#     {'bar_absolute': 30.294,
#      'bar_hi_at': 1711140692,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.322,
#      'arch_int': 60,
#      'bar_lo': 30.318,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711140662,
#      'ts': 1711140720},
#     {'bar_absolute': 30.295,
#      'bar_hi_at': 1711140753,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.323,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.323,
#      'bar_lo_at': 1711140723,
#      'ts': 1711140780},
#     {'bar_absolute': 30.294,
#      'bar_hi_at': 1711140783,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.322,
#      'arch_int': 60,
#      'bar_lo': 30.322,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711140783,
#      'ts': 1711140840},
#     {'bar_absolute': 30.295,
#      'bar_hi_at': 1711140875,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.323,
#      'arch_int': 60,
#      'bar_lo': 30.32,
#      'bar_hi': 30.323,
#      'bar_lo_at': 1711140844,
#      'ts': 1711140900},
#     {'bar_absolute': 30.296,
#      'bar_hi_at': 1711140905,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.324,
#      'arch_int': 60,
#      'bar_lo': 30.324,
#      'bar_hi': 30.324,
#      'bar_lo_at': 1711140905,
#      'ts': 1711140960},
#     {'bar_absolute': 30.295,
#      'bar_hi_at': 1711140966,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.323,
#      'arch_int': 60,
#      'bar_lo': 30.323,
#      'bar_hi': 30.323,
#      'bar_lo_at': 1711140966,
#      'ts': 1711141020},
#     {'bar_absolute': 30.294,
#      'bar_hi_at': 1711141027,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.322,
#      'arch_int': 60,
#      'bar_lo': 30.322,
#      'bar_hi': 30.324,
#      'bar_lo_at': 1711141058,
#      'ts': 1711141080},
#     {'bar_absolute': 30.297,
#      'bar_hi_at': 1711141119,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.325,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.325,
#      'bar_lo_at': 1711141088,
#      'ts': 1711141140},
#     {'bar_absolute': 30.293,
#      'bar_hi_at': 1711141149,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.321,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.325,
#      'bar_lo_at': 1711141180,
#      'ts': 1711141200},
#     {'bar_absolute': 30.295,
#      'bar_hi_at': 1711141240,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.323,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.323,
#      'bar_lo_at': 1711141210,
#      'ts': 1711141260},
#     {'bar_absolute': 30.294,
#      'bar_hi_at': 1711141271,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.322,
#      'arch_int': 60,
#      'bar_lo': 30.322,
#      'bar_hi': 30.323,
#      'bar_lo_at': 1711141301,
#      'ts': 1711141320},
#     {'bar_absolute': 30.292,
#      'bar_hi_at': 1711141332,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.32,
#      'arch_int': 60,
#      'bar_lo': 30.32,
#      'bar_hi': 30.32,
#      'bar_lo_at': 1711141332,
#      'ts': 1711141380},
#     {'bar_absolute': 30.292,
#      'bar_hi_at': 1711141393,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.32,
#      'arch_int': 60,
#      'bar_lo': 30.32,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711141423,
#      'ts': 1711141440},
#     {'bar_absolute': 30.294,
#      'bar_hi_at': 1711141454,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.322,
#      'arch_int': 60,
#      'bar_lo': 30.322,
#      'bar_hi': 30.323,
#      'bar_lo_at': 1711141484,
#      'ts': 1711141500},
#     {'bar_absolute': 30.297,
#      'bar_hi_at': 1711141545,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.325,
#      'arch_int': 60,
#      'bar_lo': 30.324,
#      'bar_hi': 30.325,
#      'bar_lo_at': 1711141515,
#      'ts': 1711141560},
#     {'bar_absolute': 30.295,
#      'bar_hi_at': 1711141576,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.323,
#      'arch_int': 60,
#      'bar_lo': 30.323,
#      'bar_hi': 30.325,
#      'bar_lo_at': 1711141606,
#      'ts': 1711141620},
#     {'bar_absolute': 30.294,
#      'bar_hi_at': 1711141637,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.322,
#      'arch_int': 60,
#      'bar_lo': 30.322,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711141637,
#      'ts': 1711141680},
#     {'bar_absolute': 30.294,
#      'bar_hi_at': 1711141698,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.322,
#      'arch_int': 60,
#      'bar_lo': 30.322,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711141698,
#      'ts': 1711141740},
#     {'bar_absolute': 30.292,
#      'bar_hi_at': 1711141758,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.32,
#      'arch_int': 60,
#      'bar_lo': 30.32,
#      'bar_hi': 30.321,
#      'bar_lo_at': 1711141789,
#      'ts': 1711141800},
#     {'bar_absolute': 30.29,
#      'bar_hi_at': 1711141819,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.318,
#      'arch_int': 60,
#      'bar_lo': 30.318,
#      'bar_hi': 30.319,
#      'bar_lo_at': 1711141850,
#      'ts': 1711141860},
#     {'bar_absolute': 30.291,
#      'bar_hi_at': 1711141880,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.319,
#      'arch_int': 60,
#      'bar_lo': 30.319,
#      'bar_hi': 30.319,
#      'bar_lo_at': 1711141880,
#      'ts': 1711141920},
#     {'bar_absolute': 30.292,
#      'bar_hi_at': 1711141941,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.32,
#      'arch_int': 60,
#      'bar_lo': 30.32,
#      'bar_hi': 30.32,
#      'bar_lo_at': 1711141941,
#      'ts': 1711141980},
#     {'bar_absolute': 30.292,
#      'bar_hi_at': 1711142002,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.32,
#      'arch_int': 60,
#      'bar_lo': 30.32,
#      'bar_hi': 30.32,
#      'bar_lo_at': 1711142002,
#      'ts': 1711142040},
#     {'bar_absolute': 30.293,
#      'bar_hi_at': 1711142094,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.321,
#      'arch_int': 60,
#      'bar_lo': 30.32,
#      'bar_hi': 30.321,
#      'bar_lo_at': 1711142063,
#      'ts': 1711142100},
#     {'bar_absolute': 30.29,
#      'bar_hi_at': 1711142124,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.318,
#      'arch_int': 60,
#      'bar_lo': 30.318,
#      'bar_hi': 30.32,
#      'bar_lo_at': 1711142155,
#      'ts': 1711142160},
#     {'bar_absolute': 30.293,
#      'bar_hi_at': 1711142185,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.321,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.321,
#      'bar_lo_at': 1711142185,
#      'ts': 1711142220},
#     {'bar_absolute': 30.292,
#      'bar_hi_at': 1711142246,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.32,
#      'arch_int': 60,
#      'bar_lo': 30.32,
#      'bar_hi': 30.32,
#      'bar_lo_at': 1711142246,
#      'ts': 1711142280},
#     {'bar_absolute': 30.293,
#      'bar_hi_at': 1711142307,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.321,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711142337,
#      'ts': 1711142340},
#     {'bar_absolute': 30.293,
#      'bar_hi_at': 1711142368,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.321,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.321,
#      'bar_lo_at': 1711142368,
#      'ts': 1711142400},
#     {'bar_absolute': 30.293,
#      'bar_hi_at': 1711142429,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.321,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711142459,
#      'ts': 1711142460},
#     {'bar_absolute': 30.293,
#      'bar_hi_at': 1711142490,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.321,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.321,
#      'bar_lo_at': 1711142490,
#      'ts': 1711142520},
#     {'bar_absolute': 30.292,
#      'bar_hi_at': 1711142520,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.32,
#      'arch_int': 60,
#      'bar_lo': 30.32,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711142551,
#      'ts': 1711142580},
#     {'bar_absolute': 30.29,
#      'bar_hi_at': 1711142581,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.318,
#      'arch_int': 60,
#      'bar_lo': 30.318,
#      'bar_hi': 30.32,
#      'bar_lo_at': 1711142612,
#      'ts': 1711142640},
#     {'bar_absolute': 30.293,
#      'bar_hi_at': 1711142642,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.321,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711142673,
#      'ts': 1711142700},
#     {'bar_absolute': 30.291,
#      'bar_hi_at': 1711142733,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.319,
#      'arch_int': 60,
#      'bar_lo': 30.318,
#      'bar_hi': 30.319,
#      'bar_lo_at': 1711142703,
#      'ts': 1711142760},
#     {'bar_absolute': 30.294,
#      'bar_hi_at': 1711142764,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.322,
#      'arch_int': 60,
#      'bar_lo': 30.322,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711142764,
#      'ts': 1711142820},
#     {'bar_absolute': 30.3,
#      'bar_hi_at': 1711142855,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.328,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.328,
#      'bar_lo_at': 1711142825,
#      'ts': 1711142880},
#     {'bar_absolute': 30.297,
#      'bar_hi_at': 1711142916,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.325,
#      'arch_int': 60,
#      'bar_lo': 30.324,
#      'bar_hi': 30.325,
#      'bar_lo_at': 1711142886,
#      'ts': 1711142940},
#     {'bar_absolute': 30.296,
#      'bar_hi_at': 1711142947,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.324,
#      'arch_int': 60,
#      'bar_lo': 30.324,
#      'bar_hi': 30.325,
#      'bar_lo_at': 1711142977,
#      'ts': 1711143000},
#     {'bar_absolute': 30.293,
#      'bar_hi_at': 1711143008,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.321,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.323,
#      'bar_lo_at': 1711143038,
#      'ts': 1711143060},
#     {'bar_absolute': 30.297,
#      'bar_hi_at': 1711143099,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.325,
#      'arch_int': 60,
#      'bar_lo': 30.323,
#      'bar_hi': 30.325,
#      'bar_lo_at': 1711143069,
#      'ts': 1711143120},
#     {'bar_absolute': 30.292,
#      'bar_hi_at': 1711143130,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.32,
#      'arch_int': 60,
#      'bar_lo': 30.32,
#      'bar_hi': 30.321,
#      'bar_lo_at': 1711143160,
#      'ts': 1711143180},
#     {'bar_absolute': 30.293,
#      'bar_hi_at': 1711143190,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.321,
#      'arch_int': 60,
#      'bar_lo': 30.321,
#      'bar_hi': 30.321,
#      'bar_lo_at': 1711143190,
#      'ts': 1711143240},
#     {'bar_absolute': 30.294,
#      'bar_hi_at': 1711143282,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.322,
#      'arch_int': 60,
#      'bar_lo': 30.32,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711143251,
#      'ts': 1711143300},
#     {'bar_absolute': 30.29,
#      'bar_hi_at': 1711143312,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.318,
#      'arch_int': 60,
#      'bar_lo': 30.318,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711143343,
#      'ts': 1711143360},
#     {'bar_absolute': 30.294,
#      'bar_hi_at': 1711143404,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.322,
#      'arch_int': 60,
#      'bar_lo': 30.318,
#      'bar_hi': 30.322,
#      'bar_lo_at': 1711143373,
#      'ts': 1711143420},
#     {'bar_absolute': 30.291,
#      'bar_hi_at': 1711143434,
#      'tz_offset': -14400,
#      'bar_sea_level': 30.319,
#      'arch_int': 60,
#      'bar_lo': 30.319,
#      'bar_hi': 30.319,
#      'bar_lo_at': 1711143434,
#      'ts': 1711143480}],
#    'sensor_type': 242,
#    'data_structure_type': 13}],
#  'generated_at': 1711144131,
#  'station_id': 81211}

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import sqlalchemy
from dateutil.tz import tzutc, tzlocal
import pytz
import os
import dataFromDavis
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame, Series
import math

#
# Create some F6 data from the API data and write to a Pandas dataFrame 
#

def getAndStore():
    
    davisAPI = dataFromDavis.dataFromDavis()
    a = davisAPI['sensors']    
    b = a[1]
    c = (b['data'])

    df = pd.DataFrame(c) 
    df.rename(columns = {'ts':'timestamp'}, inplace = True)
   
    timezone = pytz.timezone("America/New_York")
    df['timeGroup'] = pd.to_datetime(df['timestamp'], unit='s')
    df['timeGroup'] = df['timeGroup'].dt.tz_localize('UTC').dt.tz_convert('US/Eastern')
    df['localTime'] = df['timeGroup'].dt.strftime('%I:%M %p')

    df = df.loc[:,['timestamp', 'temp_hi', 'temp_hi_at','temp_lo', 'temp_lo_at', 'rainfall_in', 'dew_point_hi', 'dew_point_lo',  'rain_rate_hi_in', 'rain_rate_hi_at', 'timeGroup', 'localTime']]   
    
    print(df)
    return(df)

getAndStore()

#
# Calculate more variables from the dataFrame
#

import pandas as pd
from pandas import DataFrame, Series
import math

def createF6(df):
    max_temp  = (df.sort_values(by='temp_hi', ascending=False))
    max_T = max_temp.iloc[:1]
    max_T_time = int(max_T['temp_hi_at'])
    maxT = max_T['temp_hi'].values[0]
    maxT = round(maxT)

    min_temp  = (df.sort_values(by='temp_lo', ascending=True))
    min_T = min_temp.iloc[:1]
    min_T_time = int(min_T['temp_lo_at'])
    minT = min_T['temp_lo'].values[0]
    minT = round(minT)

    dew_max = (df.sort_values(by='dew_point_hi', ascending=False))
    dew_max1 = dew_max.iloc[:1]
    dewMax = dew_max1['dew_point_hi'].values[0]
    dewMaxT = round(dewMax)

    dew_min = (df.sort_values(by='dew_point_lo', ascending=True))
    dew_min1 = dew_min.iloc[:1]
    dewMin = dew_min1['dew_point_lo'].values[0]
    dewMinT = round(dewMin)

    rain = df['rainfall_in'].sum()
    avgTemp = math.ceil((int(maxT + minT)/2))

    hdd = (65 - avgTemp)
    if hdd < 0:
        hdd = 0
    cdd = (avgTemp - 65)
    if cdd < 0:
        cdd = 0         
     
    return(maxT, minT, dewMaxT, dewMinT, rain, avgTemp, hdd, cdd)

df = getAndStore()
createF6(df)
# Out:
#        timestamp  temp_hi  temp_hi_at  temp_lo  temp_lo_at  rainfall_in  \
# 0     1711056660     43.6  1711056614     43.6  1711056614            0
# 1     1711056720     43.6  1711056677     43.6  1711056677            0
# 2     1711056780     43.6  1711056740     43.6  1711056740            0
# 3     1711056840     43.6  1711056792     43.6  1711056792            0
# 4     1711056900     43.7  1711056887     43.6  1711056855            0
# ...          ...      ...         ...      ...         ...          ...
# 1435  1711142760     39.1  1711142717     39.0  1711142728            0
# 1436  1711142820     39.1  1711142780     39.0  1711142812            0
# 1437  1711142880     39.2  1711142875     39.1  1711142833            0
# 1438  1711142940     39.1  1711142896     39.1  1711142896            0
# 1439  1711143000     39.2  1711142959     39.1  1711142980            0
#
#       dew_point_hi  dew_point_lo  rain_rate_hi_in  rain_rate_hi_at  \
# 0             11.8          11.7                0       1711056609
# 1             11.7          11.4                0       1711056661
# 2             11.7          11.7                0       1711056724
# 3             12.0          12.0                0       1711056787
# 4             12.2          11.9                0       1711056850
# ...            ...           ...              ...              ...
# 1435          28.2          28.1                0       1711142701
# 1436          28.3          28.2                0       1711142764
# 1437          28.4          28.3                0       1711142827
# 1438          28.4          28.4                0       1711142880
# 1439          28.5          28.4                0       1711142943
#
#                      timeGroup localTime
# 0    2024-03-21 17:31:00-04:00  05:31 PM
# 1    2024-03-21 17:32:00-04:00  05:32 PM
# 2    2024-03-21 17:33:00-04:00  05:33 PM
# 3    2024-03-21 17:34:00-04:00  05:34 PM
# 4    2024-03-21 17:35:00-04:00  05:35 PM
# ...                        ...       ...
# 1435 2024-03-22 17:26:00-04:00  05:26 PM
# 1436 2024-03-22 17:27:00-04:00  05:27 PM
# 1437 2024-03-22 17:28:00-04:00  05:28 PM
# 1438 2024-03-22 17:29:00-04:00  05:29 PM
# 1439 2024-03-22 17:30:00-04:00  05:30 PM
#
# [1440 rows x 12 columns]
#        timestamp  temp_hi  temp_hi_at  temp_lo  temp_lo_at  rainfall_in  \
# 0     1711056660     43.6  1711056614     43.6  1711056614            0
# 1     1711056720     43.6  1711056677     43.6  1711056677            0
# 2     1711056780     43.6  1711056740     43.6  1711056740            0
# 3     1711056840     43.6  1711056792     43.6  1711056792            0
# 4     1711056900     43.7  1711056887     43.6  1711056855            0
# ...          ...      ...         ...      ...         ...          ...
# 1435  1711142760     39.1  1711142717     39.0  1711142728            0
# 1436  1711142820     39.1  1711142780     39.0  1711142812            0
# 1437  1711142880     39.2  1711142875     39.1  1711142833            0
# 1438  1711142940     39.1  1711142896     39.1  1711142896            0
# 1439  1711143000     39.2  1711142959     39.1  1711142980            0
#
#       dew_point_hi  dew_point_lo  rain_rate_hi_in  rain_rate_hi_at  \
# 0             11.8          11.7                0       1711056609
# 1             11.7          11.4                0       1711056661
# 2             11.7          11.7                0       1711056724
# 3             12.0          12.0                0       1711056787
# 4             12.2          11.9                0       1711056850
# ...            ...           ...              ...              ...
# 1435          28.2          28.1                0       1711142701
# 1436          28.3          28.2                0       1711142764
# 1437          28.4          28.3                0       1711142827
# 1438          28.4          28.4                0       1711142880
# 1439          28.5          28.4                0       1711142943
#
#                      timeGroup localTime
# 0    2024-03-21 17:31:00-04:00  05:31 PM
# 1    2024-03-21 17:32:00-04:00  05:32 PM
# 2    2024-03-21 17:33:00-04:00  05:33 PM
# 3    2024-03-21 17:34:00-04:00  05:34 PM
# 4    2024-03-21 17:35:00-04:00  05:35 PM
# ...                        ...       ...
# 1435 2024-03-22 17:26:00-04:00  05:26 PM
# 1436 2024-03-22 17:27:00-04:00  05:27 PM
# 1437 2024-03-22 17:28:00-04:00  05:28 PM
# 1438 2024-03-22 17:29:00-04:00  05:29 PM
# 1439 2024-03-22 17:30:00-04:00  05:30 PM
#
# [1440 rows x 12 columns]
# (44, 26, 28, 11, 0, 35, 30, 0)

# %%
import sandbox1
import sandbox2
import daysAndDatesNew
import createF6

#
# Import data for use in the alamanc
#

dayInfo = daysAndDatesNew.daysAndDatesNew()
month, month_num, date, year = dayInfo[0], dayInfo[1], dayInfo[2], dayInfo[3]
yesterday = int(dayInfo[4])
nextDay = int(dayInfo[5])

sdf = createF6.createF6(df)
print(sdf)
maxT, minT, dewMaxT, throttle, rain, avgTemp, hdd, cdd = sdf[0], sdf[1], sdf[2], sdf[3], sdf[4], sdf[5], sdf[6], sdf[7]

nmlData = sandbox2.sandbox2()
nmlHi = nmlData[3]
nmlLo = nmlData[4]

highData = sandbox1.recordHigh()
lowData = sandbox1.recordLow()
rainData = sandbox1.recordRain()

highPhrase = highData[2]
lowPhrase = lowData[2]
rainPhrase = rainData[2]

#filePath = '/var/www/html/000/climoDavisTest111.txt'
filePath = '/Users/jameshayes/Sites/climoDavis999.txt'

def almanac():
    
    """Set and and write the daily almanac"""

    with open(f'{filePath}','w') as outfile1: 
    #with open('/var/www/html/000/climoDavisText.txt','w') as outfile1: 
        print(f'Daily almanac for {month} {date}, {year}', file = outfile1)
        print('\n', file = outfile1)
        print(f'The high so far today is {maxT} degrees', file = outfile1)
        print(f'The low so far today is {minT} degrees', file = outfile1)
        print(f'The average temperature is {avgTemp} degrees', file = outfile1)
        print(f'The rainfall so far today is {("%.2f" % rain)} inches', file = outfile1)
        if hdd == 0:
            print('')
        else:
            print(f'There were {hdd} heating degree days', file = outfile1)
        if cdd == 0:
            print('')
        else:
            print(f'There were {cdd} cooling degree days', file = outfile1)
            
        print('\n', file = outfile1)        
    
    
        if date == 1:
            print(f'Normal and Record information for {nextMonth} {nextDay}, {year}', file = outfile1)
            print('\n', file = outfile1)
            print(f'The normal high for today is {nmlHi} degrees', file = outfile1)
            print(f'The normal low for today is {nmlLo} degrees' , file = outfile1)
            print('\n', file = outfile1)
            print(highPhrase, file = outfile1)
            print(lowPhrase, file = outfile1)
            print(rainPhrase, file = outfile1)  
        
        else:
            print(f'Normal and Record information for {month} {date}, {year}', file = outfile1)
            print('\n', file = outfile1)
            print(f'The normal high for today is {nmlHi} degrees', file = outfile1)
            print(f'The normal low for today is {nmlLo} degrees' , file = outfile1)
            print('\n', file = outfile1)
            print(highPhrase, file = outfile1)
            print(lowPhrase, file = outfile1)
            print(rainPhrase, file = outfile1)
# Out:
# ('March', '03', '21', '2024')
# (44, 26, 28, 11, 0, 35, 30, 0)
# 1
# 2003
